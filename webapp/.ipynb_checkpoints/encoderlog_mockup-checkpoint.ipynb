# %%
import os
import re
channel="nick_rom"
txdate="2019-11-07"

# %%
regex_breaknumber=r"INFO: ([a-zA-Z\s]*) - ([\d-]*) converting break:([\d]*)"
break_number=0
with open(os.path.join("/ddrive/streams",channel,"commercials/playlists",txdate,"encode.log")) as file:
    for line in file:
        print(line)
        match=re.search(regex_breaknumber,line)
        if match:
            if break_number>0:
                pass
            break_number=int(match.group(3))
# Out:
# 2019-11-07 12:40:13,053 INFO: Hello from encode_nicktoons.py [in ./utils/encode_nicktoons.py:179]
#
# 2019-11-07 12:40:13,095 INFO: Missing commercials: [in ./utils/encode_nicktoons.py:184]
#
# 2019-11-07 12:40:13,101 INFO: All files found. Good. [in ./utils/encode_nicktoons.py:203]
#
# 2019-11-07 12:40:13,240 INFO: Nick Romania - 2019-11-07 converting break:1 [in ./utils/encode_nicktoons.py:214]
#
# 2019-11-07 12:40:13,240 INFO:
#
# concat name=c_v adjust-base=false
#
# concat name=c_a1 adjust-base=false
#
# mpegtsmux name=mux prog-map=program_map,PCR_30633=sink_1401,sink_1401=30633,sink_1461=30633,sink_1462=30633,sink_1463=30633,sink_1464=30633,sink_1465=30633,sink_1490=30633,PMT_30633=1402
#
# multiqueue name=q max-size-buffers=23 max-size-bytes=0 max-size-time=0 sync-by-running-time=TRUE
#
# streamsynchronizer name=sync
#
# filesrc location="/ddrive/commercials/ABC821747.mxf" ! decodebin name=d0 d0. ! queue ! video/x-raw ! c_v. d0. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17458.mxf" ! decodebin name=d1 d1. ! queue ! video/x-raw ! c_v. d1. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17409.mxf" ! decodebin name=d2 d2. ! queue ! video/x-raw ! c_v. d2. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17376.mxf" ! decodebin name=d3 d3. ! queue ! video/x-raw ! c_v. d3. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO15645.mxf" ! decodebin name=d4 d4. ! queue ! video/x-raw ! c_v. d4. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17009.mxf" ! decodebin name=d5 d5. ! queue ! video/x-raw ! c_v. d5. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17243.mxf" ! decodebin name=d6 d6. ! queue ! video/x-raw ! c_v. d6. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO15310.mxf" ! decodebin name=d7 d7. ! queue ! video/x-raw ! c_v. d7. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17252.mxf" ! decodebin name=d8 d8. ! queue ! video/x-raw ! c_v. d8. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17214.mxf" ! decodebin name=d9 d9. ! queue ! video/x-raw ! c_v. d9. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17498.mxf" ! decodebin name=d10 d10. ! queue ! video/x-raw ! c_v. d10. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17499.mxf" ! decodebin name=d11 d11. ! queue ! video/x-raw ! c_v. d11. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17028.mxf" ! decodebin name=d12 d12. ! queue ! video/x-raw ! c_v. d12. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17502.mxf" ! decodebin name=d13 d13. ! queue ! video/x-raw ! c_v. d13. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17538.mxf" ! decodebin name=d14 d14. ! queue ! video/x-raw ! c_v. d14. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17522.mxf" ! decodebin name=d15 d15. ! queue ! video/x-raw ! c_v. d15. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17520.mxf" ! decodebin name=d16 d16. ! queue ! video/x-raw ! c_v. d16. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17494.mxf" ! decodebin name=d17 d17. ! queue ! video/x-raw ! c_v. d17. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17483.mxf" ! decodebin name=d18 d18. ! queue ! video/x-raw ! c_v. d18. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/ABC821749.mxf" ! decodebin name=d19 d19. ! queue ! video/x-raw ! c_v. d19. ! queue ! audio/x-raw ! c_a1.
#
#
#
# c_v. ! sync. sync. ! videoconvert ! videoscale ! video/x-raw,width=720,height=576 ! identity single-segment=true silent=false !
#
#   avenc_mpeg2video bitrate=3096000 ! video/mpeg,mpegversion=2 ! mpegvideoparse ! q.sink_1 q.src_1 ! mux.sink_1401
#
# c_a1. ! sync. sync. ! audioconvert ! audio/x-raw,channels=2 ! audioresample ! identity single-segment=true !
#
# avenc_mp2 bitrate=192000 ! mpegaudioparse ! tee name=t
#
#   t.src_0 ! q.sink_2 q.src_2 ! mux.sink_1461
#
#   t.src_1 ! q.sink_3 q.src_3 ! mux.sink_1462
#
#   t.src_2 ! q.sink_4 q.src_4 ! mux.sink_1463
#
#   t.src_3 ! q.sink_5 q.src_5 ! mux.sink_1464
#
#   t.src_4 ! q.sink_6 q.src_6 ! mux.sink_1465
#
# fakesrc num-buffers=1 sizetype=2 sizemax=5 ! application/x-teletext ! q.sink_8 q.sink_8 ! mux.sink_1490
#
# mux.src ! tsparse parse-private-sections=true name=p p.program_30633 !
#
# multifilesink location=/ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_01/segment_%05d.ts
#
#   next-file=3 max-files=0 max-file-size=0 post-messages=true
#
#  [in ./utils/encode_nicktoons.py:215]
#
# 2019-11-07 12:40:18,490 ERROR: Error: gst-stream-error-quark: Internal data stream error. (1): mxfdemux.c(3257): gst_mxf_demux_loop (): /GstPipeline:pipeline0/GstDecodeBin:d0/GstMXFDemux:mxfdemux0:
#
# streaming stopped, reason error (-5)
#
#  [in ./utils/encode_nicktoons.py:128]
#
# 2019-11-07 12:40:18,491 INFO: Setting pipline to NULL. [in ./utils/encode_nicktoons.py:156]
#
# 2019-11-07 12:40:18,929 INFO: Nick Romania - 2019-11-07 converting break:2 [in ./utils/encode_nicktoons.py:214]
#
# 2019-11-07 12:40:18,929 INFO:
#
# concat name=c_v adjust-base=false
#
# concat name=c_a1 adjust-base=false
#
# mpegtsmux name=mux prog-map=program_map,PCR_30633=sink_1401,sink_1401=30633,sink_1461=30633,sink_1462=30633,sink_1463=30633,sink_1464=30633,sink_1465=30633,sink_1490=30633,PMT_30633=1402
#
# multiqueue name=q max-size-buffers=23 max-size-bytes=0 max-size-time=0 sync-by-running-time=TRUE
#
# streamsynchronizer name=sync
#
# filesrc location="/ddrive/commercials/ABC821743.mxf" ! decodebin name=d0 d0. ! queue ! video/x-raw ! c_v. d0. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17482.mxf" ! decodebin name=d1 d1. ! queue ! video/x-raw ! c_v. d1. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17028.mxf" ! decodebin name=d2 d2. ! queue ! video/x-raw ! c_v. d2. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17520.mxf" ! decodebin name=d3 d3. ! queue ! video/x-raw ! c_v. d3. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17522.mxf" ! decodebin name=d4 d4. ! queue ! video/x-raw ! c_v. d4. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17494.mxf" ! decodebin name=d5 d5. ! queue ! video/x-raw ! c_v. d5. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17493.mxf" ! decodebin name=d6 d6. ! queue ! video/x-raw ! c_v. d6. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17590.mxf" ! decodebin name=d7 d7. ! queue ! video/x-raw ! c_v. d7. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17538.mxf" ! decodebin name=d8 d8. ! queue ! video/x-raw ! c_v. d8. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17502.mxf" ! decodebin name=d9 d9. ! queue ! video/x-raw ! c_v. d9. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17499.mxf" ! decodebin name=d10 d10. ! queue ! video/x-raw ! c_v. d10. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17314.mxf" ! decodebin name=d11 d11. ! queue ! video/x-raw ! c_v. d11. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16119.mxf" ! decodebin name=d12 d12. ! queue ! video/x-raw ! c_v. d12. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17243.mxf" ! decodebin name=d13 d13. ! queue ! video/x-raw ! c_v. d13. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO14307.mxf" ! decodebin name=d14 d14. ! queue ! video/x-raw ! c_v. d14. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16957.mxf" ! decodebin name=d15 d15. ! queue ! video/x-raw ! c_v. d15. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17261.mxf" ! decodebin name=d16 d16. ! queue ! video/x-raw ! c_v. d16. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17587.mxf" ! decodebin name=d17 d17. ! queue ! video/x-raw ! c_v. d17. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO15310.mxf" ! decodebin name=d18 d18. ! queue ! video/x-raw ! c_v. d18. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17482.mxf" ! decodebin name=d19 d19. ! queue ! video/x-raw ! c_v. d19. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/ABC821739.mxf" ! decodebin name=d20 d20. ! queue ! video/x-raw ! c_v. d20. ! queue ! audio/x-raw ! c_a1.
#
#
#
# c_v. ! sync. sync. ! videoconvert ! videoscale ! video/x-raw,width=720,height=576 ! identity single-segment=true silent=false !
#
#   avenc_mpeg2video bitrate=3096000 ! video/mpeg,mpegversion=2 ! mpegvideoparse ! q.sink_1 q.src_1 ! mux.sink_1401
#
# c_a1. ! sync. sync. ! audioconvert ! audio/x-raw,channels=2 ! audioresample ! identity single-segment=true !
#
# avenc_mp2 bitrate=192000 ! mpegaudioparse ! tee name=t
#
#   t.src_0 ! q.sink_2 q.src_2 ! mux.sink_1461
#
#   t.src_1 ! q.sink_3 q.src_3 ! mux.sink_1462
#
#   t.src_2 ! q.sink_4 q.src_4 ! mux.sink_1463
#
#   t.src_3 ! q.sink_5 q.src_5 ! mux.sink_1464
#
#   t.src_4 ! q.sink_6 q.src_6 ! mux.sink_1465
#
# fakesrc num-buffers=1 sizetype=2 sizemax=5 ! application/x-teletext ! q.sink_8 q.sink_8 ! mux.sink_1490
#
# mux.src ! tsparse parse-private-sections=true name=p p.program_30633 !
#
# multifilesink location=/ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_02/segment_%05d.ts
#
#   next-file=3 max-files=0 max-file-size=0 post-messages=true
#
#  [in ./utils/encode_nicktoons.py:215]
#
# 2019-11-07 12:40:20,754 ERROR: Error: gst-stream-error-quark: Internal data stream error. (1): mxfdemux.c(3257): gst_mxf_demux_loop (): /GstPipeline:pipeline1/GstDecodeBin:d0/GstMXFDemux:mxfdemux36:
#
# streaming stopped, reason error (-5)
#
#  [in ./utils/encode_nicktoons.py:128]
#
# 2019-11-07 12:40:20,754 INFO: Setting pipline to NULL. [in ./utils/encode_nicktoons.py:156]
#
# 2019-11-07 12:40:20,849 INFO: Nick Romania - 2019-11-07 converting break:3 [in ./utils/encode_nicktoons.py:214]
#
# 2019-11-07 12:40:20,849 INFO:
#
# concat name=c_v adjust-base=false
#
# concat name=c_a1 adjust-base=false
#
# mpegtsmux name=mux prog-map=program_map,PCR_30633=sink_1401,sink_1401=30633,sink_1461=30633,sink_1462=30633,sink_1463=30633,sink_1464=30633,sink_1465=30633,sink_1490=30633,PMT_30633=1402
#
# multiqueue name=q max-size-buffers=23 max-size-bytes=0 max-size-time=0 sync-by-running-time=TRUE
#
# streamsynchronizer name=sync
#
# filesrc location="/ddrive/commercials/ABC821742.mxf" ! decodebin name=d0 d0. ! queue ! video/x-raw ! c_v. d0. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17306.mxf" ! decodebin name=d1 d1. ! queue ! video/x-raw ! c_v. d1. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17409.mxf" ! decodebin name=d2 d2. ! queue ! video/x-raw ! c_v. d2. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17376.mxf" ! decodebin name=d3 d3. ! queue ! video/x-raw ! c_v. d3. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16945.mxf" ! decodebin name=d4 d4. ! queue ! video/x-raw ! c_v. d4. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17521.mxf" ! decodebin name=d5 d5. ! queue ! video/x-raw ! c_v. d5. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17522.mxf" ! decodebin name=d6 d6. ! queue ! video/x-raw ! c_v. d6. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17493.mxf" ! decodebin name=d7 d7. ! queue ! video/x-raw ! c_v. d7. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17524.mxf" ! decodebin name=d8 d8. ! queue ! video/x-raw ! c_v. d8. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17523.mxf" ! decodebin name=d9 d9. ! queue ! video/x-raw ! c_v. d9. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17491.mxf" ! decodebin name=d10 d10. ! queue ! video/x-raw ! c_v. d10. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17494.mxf" ! decodebin name=d11 d11. ! queue ! video/x-raw ! c_v. d11. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17520.mxf" ! decodebin name=d12 d12. ! queue ! video/x-raw ! c_v. d12. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17538.mxf" ! decodebin name=d13 d13. ! queue ! video/x-raw ! c_v. d13. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17028.mxf" ! decodebin name=d14 d14. ! queue ! video/x-raw ! c_v. d14. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17498.mxf" ! decodebin name=d15 d15. ! queue ! video/x-raw ! c_v. d15. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17547.mxf" ! decodebin name=d16 d16. ! queue ! video/x-raw ! c_v. d16. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17544.mxf" ! decodebin name=d17 d17. ! queue ! video/x-raw ! c_v. d17. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO11661.mxf" ! decodebin name=d18 d18. ! queue ! video/x-raw ! c_v. d18. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17458.mxf" ! decodebin name=d19 d19. ! queue ! video/x-raw ! c_v. d19. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17484.mxf" ! decodebin name=d20 d20. ! queue ! video/x-raw ! c_v. d20. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/ABC821749.mxf" ! decodebin name=d21 d21. ! queue ! video/x-raw ! c_v. d21. ! queue ! audio/x-raw ! c_a1.
#
#
#
# c_v. ! sync. sync. ! videoconvert ! videoscale ! video/x-raw,width=720,height=576 ! identity single-segment=true silent=false !
#
#   avenc_mpeg2video bitrate=3096000 ! video/mpeg,mpegversion=2 ! mpegvideoparse ! q.sink_1 q.src_1 ! mux.sink_1401
#
# c_a1. ! sync. sync. ! audioconvert ! audio/x-raw,channels=2 ! audioresample ! identity single-segment=true !
#
# avenc_mp2 bitrate=192000 ! mpegaudioparse ! tee name=t
#
#   t.src_0 ! q.sink_2 q.src_2 ! mux.sink_1461
#
#   t.src_1 ! q.sink_3 q.src_3 ! mux.sink_1462
#
#   t.src_2 ! q.sink_4 q.src_4 ! mux.sink_1463
#
#   t.src_3 ! q.sink_5 q.src_5 ! mux.sink_1464
#
#   t.src_4 ! q.sink_6 q.src_6 ! mux.sink_1465
#
# fakesrc num-buffers=1 sizetype=2 sizemax=5 ! application/x-teletext ! q.sink_8 q.sink_8 ! mux.sink_1490
#
# mux.src ! tsparse parse-private-sections=true name=p p.program_30633 !
#
# multifilesink location=/ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_03/segment_%05d.ts
#
#   next-file=3 max-files=0 max-file-size=0 post-messages=true
#
#  [in ./utils/encode_nicktoons.py:215]
#
# 2019-11-07 12:40:22,046 ERROR: Error: gst-stream-error-quark: Internal data stream error. (1): mxfdemux.c(3257): gst_mxf_demux_loop (): /GstPipeline:pipeline2/GstDecodeBin:d0/GstMXFDemux:mxfdemux56:
#
# streaming stopped, reason error (-5)
#
#  [in ./utils/encode_nicktoons.py:128]
#
# 2019-11-07 12:40:22,047 INFO: Setting pipline to NULL. [in ./utils/encode_nicktoons.py:156]
#
# 2019-11-07 12:40:22,303 INFO: Nick Romania - 2019-11-07 converting break:4 [in ./utils/encode_nicktoons.py:214]
#
# 2019-11-07 12:40:22,303 INFO:
#
# concat name=c_v adjust-base=false
#
# concat name=c_a1 adjust-base=false
#
# mpegtsmux name=mux prog-map=program_map,PCR_30633=sink_1401,sink_1401=30633,sink_1461=30633,sink_1462=30633,sink_1463=30633,sink_1464=30633,sink_1465=30633,sink_1490=30633,PMT_30633=1402
#
# multiqueue name=q max-size-buffers=23 max-size-bytes=0 max-size-time=0 sync-by-running-time=TRUE
#
# streamsynchronizer name=sync
#
# filesrc location="/ddrive/commercials/ABC821747.mxf" ! decodebin name=d0 d0. ! queue ! video/x-raw ! c_v. d0. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17297.mxf" ! decodebin name=d1 d1. ! queue ! video/x-raw ! c_v. d1. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17214.mxf" ! decodebin name=d2 d2. ! queue ! video/x-raw ! c_v. d2. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17587.mxf" ! decodebin name=d3 d3. ! queue ! video/x-raw ! c_v. d3. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17385.mxf" ! decodebin name=d4 d4. ! queue ! video/x-raw ! c_v. d4. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17184.mxf" ! decodebin name=d5 d5. ! queue ! video/x-raw ! c_v. d5. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17403.mxf" ! decodebin name=d6 d6. ! queue ! video/x-raw ! c_v. d6. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17469.mxf" ! decodebin name=d7 d7. ! queue ! video/x-raw ! c_v. d7. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17502.mxf" ! decodebin name=d8 d8. ! queue ! video/x-raw ! c_v. d8. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17494.mxf" ! decodebin name=d9 d9. ! queue ! video/x-raw ! c_v. d9. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17028.mxf" ! decodebin name=d10 d10. ! queue ! video/x-raw ! c_v. d10. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17538.mxf" ! decodebin name=d11 d11. ! queue ! video/x-raw ! c_v. d11. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17330.mxf" ! decodebin name=d12 d12. ! queue ! video/x-raw ! c_v. d12. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17522.mxf" ! decodebin name=d13 d13. ! queue ! video/x-raw ! c_v. d13. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17520.mxf" ! decodebin name=d14 d14. ! queue ! video/x-raw ! c_v. d14. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17500.mxf" ! decodebin name=d15 d15. ! queue ! video/x-raw ! c_v. d15. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17523.mxf" ! decodebin name=d16 d16. ! queue ! video/x-raw ! c_v. d16. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17524.mxf" ! decodebin name=d17 d17. ! queue ! video/x-raw ! c_v. d17. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/ABC821748.mxf" ! decodebin name=d18 d18. ! queue ! video/x-raw ! c_v. d18. ! queue ! audio/x-raw ! c_a1.
#
#
#
# c_v. ! sync. sync. ! videoconvert ! videoscale ! video/x-raw,width=720,height=576 ! identity single-segment=true silent=false !
#
#   avenc_mpeg2video bitrate=3096000 ! video/mpeg,mpegversion=2 ! mpegvideoparse ! q.sink_1 q.src_1 ! mux.sink_1401
#
# c_a1. ! sync. sync. ! audioconvert ! audio/x-raw,channels=2 ! audioresample ! identity single-segment=true !
#
# avenc_mp2 bitrate=192000 ! mpegaudioparse ! tee name=t
#
#   t.src_0 ! q.sink_2 q.src_2 ! mux.sink_1461
#
#   t.src_1 ! q.sink_3 q.src_3 ! mux.sink_1462
#
#   t.src_2 ! q.sink_4 q.src_4 ! mux.sink_1463
#
#   t.src_3 ! q.sink_5 q.src_5 ! mux.sink_1464
#
#   t.src_4 ! q.sink_6 q.src_6 ! mux.sink_1465
#
# fakesrc num-buffers=1 sizetype=2 sizemax=5 ! application/x-teletext ! q.sink_8 q.sink_8 ! mux.sink_1490
#
# mux.src ! tsparse parse-private-sections=true name=p p.program_30633 !
#
# multifilesink location=/ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_04/segment_%05d.ts
#
#   next-file=3 max-files=0 max-file-size=0 post-messages=true
#
#  [in ./utils/encode_nicktoons.py:215]
#
# 2019-11-07 12:40:22,371 ERROR: Error: gst-stream-error-quark: Internal data stream error. (1): mxfdemux.c(3257): gst_mxf_demux_loop (): /GstPipeline:pipeline3/GstDecodeBin:d0/GstMXFDemux:mxfdemux71:
#
# streaming stopped, reason error (-5)
#
#  [in ./utils/encode_nicktoons.py:128]
#
# 2019-11-07 12:40:22,372 INFO: Setting pipline to NULL. [in ./utils/encode_nicktoons.py:156]
#
# 2019-11-07 12:40:22,880 INFO: Nick Romania - 2019-11-07 converting break:5 [in ./utils/encode_nicktoons.py:214]
#
# 2019-11-07 12:40:22,880 INFO:
#
# concat name=c_v adjust-base=false
#
# concat name=c_a1 adjust-base=false
#
# mpegtsmux name=mux prog-map=program_map,PCR_30633=sink_1401,sink_1401=30633,sink_1461=30633,sink_1462=30633,sink_1463=30633,sink_1464=30633,sink_1465=30633,sink_1490=30633,PMT_30633=1402
#
# multiqueue name=q max-size-buffers=23 max-size-bytes=0 max-size-time=0 sync-by-running-time=TRUE
#
# streamsynchronizer name=sync
#
# filesrc location="/ddrive/commercials/ABC821743.mxf" ! decodebin name=d0 d0. ! queue ! video/x-raw ! c_v. d0. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17483.mxf" ! decodebin name=d1 d1. ! queue ! video/x-raw ! c_v. d1. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17458.mxf" ! decodebin name=d2 d2. ! queue ! video/x-raw ! c_v. d2. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17214.mxf" ! decodebin name=d3 d3. ! queue ! video/x-raw ! c_v. d3. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17028.mxf" ! decodebin name=d4 d4. ! queue ! video/x-raw ! c_v. d4. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17521.mxf" ! decodebin name=d5 d5. ! queue ! video/x-raw ! c_v. d5. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17520.mxf" ! decodebin name=d6 d6. ! queue ! video/x-raw ! c_v. d6. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17524.mxf" ! decodebin name=d7 d7. ! queue ! video/x-raw ! c_v. d7. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17494.mxf" ! decodebin name=d8 d8. ! queue ! video/x-raw ! c_v. d8. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17523.mxf" ! decodebin name=d9 d9. ! queue ! video/x-raw ! c_v. d9. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17492.mxf" ! decodebin name=d10 d10. ! queue ! video/x-raw ! c_v. d10. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17493.mxf" ! decodebin name=d11 d11. ! queue ! video/x-raw ! c_v. d11. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17538.mxf" ! decodebin name=d12 d12. ! queue ! video/x-raw ! c_v. d12. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17330.mxf" ! decodebin name=d13 d13. ! queue ! video/x-raw ! c_v. d13. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17514.mxf" ! decodebin name=d14 d14. ! queue ! video/x-raw ! c_v. d14. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17500.mxf" ! decodebin name=d15 d15. ! queue ! video/x-raw ! c_v. d15. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17522.mxf" ! decodebin name=d16 d16. ! queue ! video/x-raw ! c_v. d16. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17547.mxf" ! decodebin name=d17 d17. ! queue ! video/x-raw ! c_v. d17. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17041.mxf" ! decodebin name=d18 d18. ! queue ! video/x-raw ! c_v. d18. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/ABC821739.mxf" ! decodebin name=d19 d19. ! queue ! video/x-raw ! c_v. d19. ! queue ! audio/x-raw ! c_a1.
#
#
#
# c_v. ! sync. sync. ! videoconvert ! videoscale ! video/x-raw,width=720,height=576 ! identity single-segment=true silent=false !
#
#   avenc_mpeg2video bitrate=3096000 ! video/mpeg,mpegversion=2 ! mpegvideoparse ! q.sink_1 q.src_1 ! mux.sink_1401
#
# c_a1. ! sync. sync. ! audioconvert ! audio/x-raw,channels=2 ! audioresample ! identity single-segment=true !
#
# avenc_mp2 bitrate=192000 ! mpegaudioparse ! tee name=t
#
#   t.src_0 ! q.sink_2 q.src_2 ! mux.sink_1461
#
#   t.src_1 ! q.sink_3 q.src_3 ! mux.sink_1462
#
#   t.src_2 ! q.sink_4 q.src_4 ! mux.sink_1463
#
#   t.src_3 ! q.sink_5 q.src_5 ! mux.sink_1464
#
#   t.src_4 ! q.sink_6 q.src_6 ! mux.sink_1465
#
# fakesrc num-buffers=1 sizetype=2 sizemax=5 ! application/x-teletext ! q.sink_8 q.sink_8 ! mux.sink_1490
#
# mux.src ! tsparse parse-private-sections=true name=p p.program_30633 !
#
# multifilesink location=/ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_05/segment_%05d.ts
#
#   next-file=3 max-files=0 max-file-size=0 post-messages=true
#
#  [in ./utils/encode_nicktoons.py:215]
#
# 2019-11-07 12:40:23,083 ERROR: Error: gst-stream-error-quark: Internal data stream error. (1): mxfdemux.c(3257): gst_mxf_demux_loop (): /GstPipeline:pipeline4/GstDecodeBin:d0/GstMXFDemux:mxfdemux86:
#
# streaming stopped, reason error (-5)
#
#  [in ./utils/encode_nicktoons.py:128]
#
# 2019-11-07 12:40:23,083 INFO: Setting pipline to NULL. [in ./utils/encode_nicktoons.py:156]
#
# 2019-11-07 12:40:23,434 INFO: Nick Romania - 2019-11-07 converting break:6 [in ./utils/encode_nicktoons.py:214]
#
# 2019-11-07 12:40:23,434 INFO:
#
# concat name=c_v adjust-base=false
#
# concat name=c_a1 adjust-base=false
#
# mpegtsmux name=mux prog-map=program_map,PCR_30633=sink_1401,sink_1401=30633,sink_1461=30633,sink_1462=30633,sink_1463=30633,sink_1464=30633,sink_1465=30633,sink_1490=30633,PMT_30633=1402
#
# multiqueue name=q max-size-buffers=23 max-size-bytes=0 max-size-time=0 sync-by-running-time=TRUE
#
# streamsynchronizer name=sync
#
# filesrc location="/ddrive/commercials/ABC821748.mxf" ! decodebin name=d0 d0. ! queue ! video/x-raw ! c_v. d0. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17482.mxf" ! decodebin name=d1 d1. ! queue ! video/x-raw ! c_v. d1. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17544.mxf" ! decodebin name=d2 d2. ! queue ! video/x-raw ! c_v. d2. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17523.mxf" ! decodebin name=d3 d3. ! queue ! video/x-raw ! c_v. d3. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17520.mxf" ! decodebin name=d4 d4. ! queue ! video/x-raw ! c_v. d4. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17522.mxf" ! decodebin name=d5 d5. ! queue ! video/x-raw ! c_v. d5. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17493.mxf" ! decodebin name=d6 d6. ! queue ! video/x-raw ! c_v. d6. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17502.mxf" ! decodebin name=d7 d7. ! queue ! video/x-raw ! c_v. d7. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17494.mxf" ! decodebin name=d8 d8. ! queue ! video/x-raw ! c_v. d8. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17243.mxf" ! decodebin name=d9 d9. ! queue ! video/x-raw ! c_v. d9. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17587.mxf" ! decodebin name=d10 d10. ! queue ! video/x-raw ! c_v. d10. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17587.mxf" ! decodebin name=d11 d11. ! queue ! video/x-raw ! c_v. d11. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16957.mxf" ! decodebin name=d12 d12. ! queue ! video/x-raw ! c_v. d12. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17396.mxf" ! decodebin name=d13 d13. ! queue ! video/x-raw ! c_v. d13. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17261.mxf" ! decodebin name=d14 d14. ! queue ! video/x-raw ! c_v. d14. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO14991.mxf" ! decodebin name=d15 d15. ! queue ! video/x-raw ! c_v. d15. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16351.mxf" ! decodebin name=d16 d16. ! queue ! video/x-raw ! c_v. d16. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17482.mxf" ! decodebin name=d17 d17. ! queue ! video/x-raw ! c_v. d17. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/ABC821746.mxf" ! decodebin name=d18 d18. ! queue ! video/x-raw ! c_v. d18. ! queue ! audio/x-raw ! c_a1.
#
#
#
# c_v. ! sync. sync. ! videoconvert ! videoscale ! video/x-raw,width=720,height=576 ! identity single-segment=true silent=false !
#
#   avenc_mpeg2video bitrate=3096000 ! video/mpeg,mpegversion=2 ! mpegvideoparse ! q.sink_1 q.src_1 ! mux.sink_1401
#
# c_a1. ! sync. sync. ! audioconvert ! audio/x-raw,channels=2 ! audioresample ! identity single-segment=true !
#
# avenc_mp2 bitrate=192000 ! mpegaudioparse ! tee name=t
#
#   t.src_0 ! q.sink_2 q.src_2 ! mux.sink_1461
#
#   t.src_1 ! q.sink_3 q.src_3 ! mux.sink_1462
#
#   t.src_2 ! q.sink_4 q.src_4 ! mux.sink_1463
#
#   t.src_3 ! q.sink_5 q.src_5 ! mux.sink_1464
#
#   t.src_4 ! q.sink_6 q.src_6 ! mux.sink_1465
#
# fakesrc num-buffers=1 sizetype=2 sizemax=5 ! application/x-teletext ! q.sink_8 q.sink_8 ! mux.sink_1490
#
# mux.src ! tsparse parse-private-sections=true name=p p.program_30633 !
#
# multifilesink location=/ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_%05d.ts
#
#   next-file=3 max-files=0 max-file-size=0 post-messages=true
#
#  [in ./utils/encode_nicktoons.py:215]
#
# 2019-11-07 12:40:26,724 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00000.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:29,684 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00001.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:32,002 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00002.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:34,437 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00003.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:36,657 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00004.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:38,903 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00005.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:41,148 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00006.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:43,354 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00007.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:45,646 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00008.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:47,894 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00009.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:50,008 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00010.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:52,288 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00011.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:54,527 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00012.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:56,805 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00013.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:40:58,967 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00014.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:01,237 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00015.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:03,529 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00016.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:07,901 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00017.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:09,962 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00018.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:12,113 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00019.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:14,357 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00020.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:16,473 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00021.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:18,736 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00022.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:20,808 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00023.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:21,464 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_06/segment_00024.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:21,464 INFO: End-of-stream
#
#  [in ./utils/encode_nicktoons.py:122]
#
# 2019-11-07 12:41:21,465 INFO: Break encoding finished without errors. Playlist dumped [in ./utils/encode_nicktoons.py:124]
#
# 2019-11-07 12:41:21,465 INFO: Setting pipline to NULL. [in ./utils/encode_nicktoons.py:156]
#
# 2019-11-07 12:41:21,532 INFO: Nick Romania - 2019-11-07 converting break:7 [in ./utils/encode_nicktoons.py:214]
#
# 2019-11-07 12:41:21,532 INFO:
#
# concat name=c_v adjust-base=false
#
# concat name=c_a1 adjust-base=false
#
# mpegtsmux name=mux prog-map=program_map,PCR_30633=sink_1401,sink_1401=30633,sink_1461=30633,sink_1462=30633,sink_1463=30633,sink_1464=30633,sink_1465=30633,sink_1490=30633,PMT_30633=1402
#
# multiqueue name=q max-size-buffers=23 max-size-bytes=0 max-size-time=0 sync-by-running-time=TRUE
#
# streamsynchronizer name=sync
#
# filesrc location="/ddrive/commercials/ABC821746.mxf" ! decodebin name=d0 d0. ! queue ! video/x-raw ! c_v. d0. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17421.mxf" ! decodebin name=d1 d1. ! queue ! video/x-raw ! c_v. d1. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17526.mxf" ! decodebin name=d2 d2. ! queue ! video/x-raw ! c_v. d2. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17537.mxf" ! decodebin name=d3 d3. ! queue ! video/x-raw ! c_v. d3. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17540.mxf" ! decodebin name=d4 d4. ! queue ! video/x-raw ! c_v. d4. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17542.mxf" ! decodebin name=d5 d5. ! queue ! video/x-raw ! c_v. d5. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17539.mxf" ! decodebin name=d6 d6. ! queue ! video/x-raw ! c_v. d6. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17520.mxf" ! decodebin name=d7 d7. ! queue ! video/x-raw ! c_v. d7. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17491.mxf" ! decodebin name=d8 d8. ! queue ! video/x-raw ! c_v. d8. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17492.mxf" ! decodebin name=d9 d9. ! queue ! video/x-raw ! c_v. d9. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17522.mxf" ! decodebin name=d10 d10. ! queue ! video/x-raw ! c_v. d10. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17524.mxf" ! decodebin name=d11 d11. ! queue ! video/x-raw ! c_v. d11. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17493.mxf" ! decodebin name=d12 d12. ! queue ! video/x-raw ! c_v. d12. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17547.mxf" ! decodebin name=d13 d13. ! queue ! video/x-raw ! c_v. d13. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17544.mxf" ! decodebin name=d14 d14. ! queue ! video/x-raw ! c_v. d14. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17587.mxf" ! decodebin name=d15 d15. ! queue ! video/x-raw ! c_v. d15. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17652.mxf" ! decodebin name=d16 d16. ! queue ! video/x-raw ! c_v. d16. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17376.mxf" ! decodebin name=d17 d17. ! queue ! video/x-raw ! c_v. d17. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17484.mxf" ! decodebin name=d18 d18. ! queue ! video/x-raw ! c_v. d18. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/ABC821739.mxf" ! decodebin name=d19 d19. ! queue ! video/x-raw ! c_v. d19. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/ABC821729.mxf" ! decodebin name=d20 d20. ! queue ! video/x-raw ! c_v. d20. ! queue ! audio/x-raw ! c_a1.
#
#
#
# c_v. ! sync. sync. ! videoconvert ! videoscale ! video/x-raw,width=720,height=576 ! identity single-segment=true silent=false !
#
#   avenc_mpeg2video bitrate=3096000 ! video/mpeg,mpegversion=2 ! mpegvideoparse ! q.sink_1 q.src_1 ! mux.sink_1401
#
# c_a1. ! sync. sync. ! audioconvert ! audio/x-raw,channels=2 ! audioresample ! identity single-segment=true !
#
# avenc_mp2 bitrate=192000 ! mpegaudioparse ! tee name=t
#
#   t.src_0 ! q.sink_2 q.src_2 ! mux.sink_1461
#
#   t.src_1 ! q.sink_3 q.src_3 ! mux.sink_1462
#
#   t.src_2 ! q.sink_4 q.src_4 ! mux.sink_1463
#
#   t.src_3 ! q.sink_5 q.src_5 ! mux.sink_1464
#
#   t.src_4 ! q.sink_6 q.src_6 ! mux.sink_1465
#
# fakesrc num-buffers=1 sizetype=2 sizemax=5 ! application/x-teletext ! q.sink_8 q.sink_8 ! mux.sink_1490
#
# mux.src ! tsparse parse-private-sections=true name=p p.program_30633 !
#
# multifilesink location=/ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_%05d.ts
#
#   next-file=3 max-files=0 max-file-size=0 post-messages=true
#
#  [in ./utils/encode_nicktoons.py:215]
#
# 2019-11-07 12:41:24,695 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00000.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:27,017 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00001.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:29,209 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00002.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:31,453 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00003.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:33,679 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00004.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:35,864 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00005.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:38,506 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00006.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:40,797 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00007.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:43,565 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00008.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:47,255 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00009.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:49,454 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00010.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:51,683 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00011.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:53,873 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00012.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:56,135 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00013.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:41:58,307 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00014.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:42:00,317 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00015.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:42:02,575 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00016.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:42:04,800 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00017.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:42:06,949 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00018.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:42:10,511 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00019.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:42:12,714 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00020.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:42:15,161 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00021.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:42:17,439 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_07/segment_00022.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:42:19,151 ERROR: Error: gst-stream-error-quark: Internal data stream error. (1): mxfdemux.c(3257): gst_mxf_demux_loop (): /GstPipeline:pipeline6/GstDecodeBin:d19/GstMXFDemux:mxfdemux125:
#
# streaming stopped, reason error (-5)
#
#  [in ./utils/encode_nicktoons.py:128]
#
# 2019-11-07 12:42:19,152 INFO: Setting pipline to NULL. [in ./utils/encode_nicktoons.py:156]
#
# 2019-11-07 12:42:19,230 INFO: Nick Romania - 2019-11-07 converting break:8 [in ./utils/encode_nicktoons.py:214]
#
# 2019-11-07 12:42:19,230 INFO:
#
# concat name=c_v adjust-base=false
#
# concat name=c_a1 adjust-base=false
#
# mpegtsmux name=mux prog-map=program_map,PCR_30633=sink_1401,sink_1401=30633,sink_1461=30633,sink_1462=30633,sink_1463=30633,sink_1464=30633,sink_1465=30633,sink_1490=30633,PMT_30633=1402
#
# multiqueue name=q max-size-buffers=23 max-size-bytes=0 max-size-time=0 sync-by-running-time=TRUE
#
# streamsynchronizer name=sync
#
# filesrc location="/ddrive/commercials/ABC821748.mxf" ! decodebin name=d0 d0. ! queue ! video/x-raw ! c_v. d0. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17482.mxf" ! decodebin name=d1 d1. ! queue ! video/x-raw ! c_v. d1. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17307.mxf" ! decodebin name=d2 d2. ! queue ! video/x-raw ! c_v. d2. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17041.mxf" ! decodebin name=d3 d3. ! queue ! video/x-raw ! c_v. d3. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17587.mxf" ! decodebin name=d4 d4. ! queue ! video/x-raw ! c_v. d4. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17297.mxf" ! decodebin name=d5 d5. ! queue ! video/x-raw ! c_v. d5. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17520.mxf" ! decodebin name=d6 d6. ! queue ! video/x-raw ! c_v. d6. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17522.mxf" ! decodebin name=d7 d7. ! queue ! video/x-raw ! c_v. d7. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17243.mxf" ! decodebin name=d8 d8. ! queue ! video/x-raw ! c_v. d8. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16957.mxf" ! decodebin name=d9 d9. ! queue ! video/x-raw ! c_v. d9. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17214.mxf" ! decodebin name=d10 d10. ! queue ! video/x-raw ! c_v. d10. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO15310.mxf" ! decodebin name=d11 d11. ! queue ! video/x-raw ! c_v. d11. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17252.mxf" ! decodebin name=d12 d12. ! queue ! video/x-raw ! c_v. d12. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17396.mxf" ! decodebin name=d13 d13. ! queue ! video/x-raw ! c_v. d13. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16937.mxf" ! decodebin name=d14 d14. ! queue ! video/x-raw ! c_v. d14. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO15976.mxf" ! decodebin name=d15 d15. ! queue ! video/x-raw ! c_v. d15. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17655.mxf" ! decodebin name=d16 d16. ! queue ! video/x-raw ! c_v. d16. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17482.mxf" ! decodebin name=d17 d17. ! queue ! video/x-raw ! c_v. d17. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/ABC821745.mxf" ! decodebin name=d18 d18. ! queue ! video/x-raw ! c_v. d18. ! queue ! audio/x-raw ! c_a1.
#
#
#
# c_v. ! sync. sync. ! videoconvert ! videoscale ! video/x-raw,width=720,height=576 ! identity single-segment=true silent=false !
#
#   avenc_mpeg2video bitrate=3096000 ! video/mpeg,mpegversion=2 ! mpegvideoparse ! q.sink_1 q.src_1 ! mux.sink_1401
#
# c_a1. ! sync. sync. ! audioconvert ! audio/x-raw,channels=2 ! audioresample ! identity single-segment=true !
#
# avenc_mp2 bitrate=192000 ! mpegaudioparse ! tee name=t
#
#   t.src_0 ! q.sink_2 q.src_2 ! mux.sink_1461
#
#   t.src_1 ! q.sink_3 q.src_3 ! mux.sink_1462
#
#   t.src_2 ! q.sink_4 q.src_4 ! mux.sink_1463
#
#   t.src_3 ! q.sink_5 q.src_5 ! mux.sink_1464
#
#   t.src_4 ! q.sink_6 q.src_6 ! mux.sink_1465
#
# fakesrc num-buffers=1 sizetype=2 sizemax=5 ! application/x-teletext ! q.sink_8 q.sink_8 ! mux.sink_1490
#
# mux.src ! tsparse parse-private-sections=true name=p p.program_30633 !
#
# multifilesink location=/ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_08/segment_%05d.ts
#
#   next-file=3 max-files=0 max-file-size=0 post-messages=true
#
#  [in ./utils/encode_nicktoons.py:215]
#
# 2019-11-07 12:42:19,975 ERROR: Error: gst-stream-error-quark: Internal data stream error. (1): mxfdemux.c(3257): gst_mxf_demux_loop (): /GstPipeline:pipeline7/GstDecodeBin:d18/GstMXFDemux:mxfdemux154:
#
# streaming stopped, reason error (-5)
#
#  [in ./utils/encode_nicktoons.py:128]
#
# 2019-11-07 12:42:19,975 INFO: Setting pipline to NULL. [in ./utils/encode_nicktoons.py:156]
#
# 2019-11-07 12:42:20,108 INFO: Nick Romania - 2019-11-07 converting break:9 [in ./utils/encode_nicktoons.py:214]
#
# 2019-11-07 12:42:20,109 INFO:
#
# concat name=c_v adjust-base=false
#
# concat name=c_a1 adjust-base=false
#
# mpegtsmux name=mux prog-map=program_map,PCR_30633=sink_1401,sink_1401=30633,sink_1461=30633,sink_1462=30633,sink_1463=30633,sink_1464=30633,sink_1465=30633,sink_1490=30633,PMT_30633=1402
#
# multiqueue name=q max-size-buffers=23 max-size-bytes=0 max-size-time=0 sync-by-running-time=TRUE
#
# streamsynchronizer name=sync
#
# filesrc location="/ddrive/commercials/ABC821739.mxf" ! decodebin name=d0 d0. ! queue ! video/x-raw ! c_v. d0. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO13963.mxf" ! decodebin name=d1 d1. ! queue ! video/x-raw ! c_v. d1. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17548.mxf" ! decodebin name=d2 d2. ! queue ! video/x-raw ! c_v. d2. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17376.mxf" ! decodebin name=d3 d3. ! queue ! video/x-raw ! c_v. d3. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17297.mxf" ! decodebin name=d4 d4. ! queue ! video/x-raw ! c_v. d4. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17541.mxf" ! decodebin name=d5 d5. ! queue ! video/x-raw ! c_v. d5. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17547.mxf" ! decodebin name=d6 d6. ! queue ! video/x-raw ! c_v. d6. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17522.mxf" ! decodebin name=d7 d7. ! queue ! video/x-raw ! c_v. d7. ! queue ! audio/x-raw ! c_a1.
#
# ...
#
# filesrc location="/ddrive/commercials/RO16419.mxf" ! decodebin name=d4 d4. ! queue ! video/x-raw ! c_v. d4. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16658.mxf" ! decodebin name=d5 d5. ! queue ! video/x-raw ! c_v. d5. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16506.mxf" ! decodebin name=d6 d6. ! queue ! video/x-raw ! c_v. d6. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16594.mxf" ! decodebin name=d7 d7. ! queue ! video/x-raw ! c_v. d7. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO14512.mxf" ! decodebin name=d8 d8. ! queue ! video/x-raw ! c_v. d8. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17301.mxf" ! decodebin name=d9 d9. ! queue ! video/x-raw ! c_v. d9. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17252.mxf" ! decodebin name=d10 d10. ! queue ! video/x-raw ! c_v. d10. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17396.mxf" ! decodebin name=d11 d11. ! queue ! video/x-raw ! c_v. d11. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16119.mxf" ! decodebin name=d12 d12. ! queue ! video/x-raw ! c_v. d12. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17385.mxf" ! decodebin name=d13 d13. ! queue ! video/x-raw ! c_v. d13. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16876.mxf" ! decodebin name=d14 d14. ! queue ! video/x-raw ! c_v. d14. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO12518.mxf" ! decodebin name=d15 d15. ! queue ! video/x-raw ! c_v. d15. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/ABC821747.mxf" ! decodebin name=d16 d16. ! queue ! video/x-raw ! c_v. d16. ! queue ! audio/x-raw ! c_a1.
#
#
#
# c_v. ! sync. sync. ! videoconvert ! videoscale ! video/x-raw,width=720,height=576 ! identity single-segment=true silent=false !
#
#   avenc_mpeg2video bitrate=3096000 ! video/mpeg,mpegversion=2 ! mpegvideoparse ! q.sink_1 q.src_1 ! mux.sink_1401
#
# c_a1. ! sync. sync. ! audioconvert ! audio/x-raw,channels=2 ! audioresample ! identity single-segment=true !
#
# avenc_mp2 bitrate=192000 ! mpegaudioparse ! tee name=t
#
#   t.src_0 ! q.sink_2 q.src_2 ! mux.sink_1461
#
#   t.src_1 ! q.sink_3 q.src_3 ! mux.sink_1462
#
#   t.src_2 ! q.sink_4 q.src_4 ! mux.sink_1463
#
#   t.src_3 ! q.sink_5 q.src_5 ! mux.sink_1464
#
#   t.src_4 ! q.sink_6 q.src_6 ! mux.sink_1465
#
# fakesrc num-buffers=1 sizetype=2 sizemax=5 ! application/x-teletext ! q.sink_8 q.sink_8 ! mux.sink_1490
#
# mux.src ! tsparse parse-private-sections=true name=p p.program_30633 !
#
# multifilesink location=/ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_40/segment_%05d.ts
#
#   next-file=3 max-files=0 max-file-size=0 post-messages=true
#
#  [in ./utils/encode_nicktoons.py:215]
#
# 2019-11-07 12:50:01,731 ERROR: Error: gst-stream-error-quark: Internal data stream error. (1): mxfdemux.c(3257): gst_mxf_demux_loop (): /GstPipeline:pipeline39/GstDecodeBin:d16/GstMXFDemux:mxfdemux741:
#
# streaming stopped, reason error (-5)
#
#  [in ./utils/encode_nicktoons.py:128]
#
# 2019-11-07 12:50:01,732 INFO: Setting pipline to NULL. [in ./utils/encode_nicktoons.py:156]
#
# 2019-11-07 12:50:01,897 INFO: Nick Romania - 2019-11-07 converting break:41 [in ./utils/encode_nicktoons.py:214]
#
# 2019-11-07 12:50:01,898 INFO:
#
# concat name=c_v adjust-base=false
#
# concat name=c_a1 adjust-base=false
#
# mpegtsmux name=mux prog-map=program_map,PCR_30633=sink_1401,sink_1401=30633,sink_1461=30633,sink_1462=30633,sink_1463=30633,sink_1464=30633,sink_1465=30633,sink_1490=30633,PMT_30633=1402
#
# multiqueue name=q max-size-buffers=23 max-size-bytes=0 max-size-time=0 sync-by-running-time=TRUE
#
# streamsynchronizer name=sync
#
# filesrc location="/ddrive/commercials/ABC821749.mxf" ! decodebin name=d0 d0. ! queue ! video/x-raw ! c_v. d0. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO12518.mxf" ! decodebin name=d1 d1. ! queue ! video/x-raw ! c_v. d1. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16876.mxf" ! decodebin name=d2 d2. ! queue ! video/x-raw ! c_v. d2. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17196.mxf" ! decodebin name=d3 d3. ! queue ! video/x-raw ! c_v. d3. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16658.mxf" ! decodebin name=d4 d4. ! queue ! video/x-raw ! c_v. d4. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16506.mxf" ! decodebin name=d5 d5. ! queue ! video/x-raw ! c_v. d5. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16369.mxf" ! decodebin name=d6 d6. ! queue ! video/x-raw ! c_v. d6. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO14561.mxf" ! decodebin name=d7 d7. ! queue ! video/x-raw ! c_v. d7. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17088.mxf" ! decodebin name=d8 d8. ! queue ! video/x-raw ! c_v. d8. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17214.mxf" ! decodebin name=d9 d9. ! queue ! video/x-raw ! c_v. d9. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16594.mxf" ! decodebin name=d10 d10. ! queue ! video/x-raw ! c_v. d10. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO15645.mxf" ! decodebin name=d11 d11. ! queue ! video/x-raw ! c_v. d11. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO14512.mxf" ! decodebin name=d12 d12. ! queue ! video/x-raw ! c_v. d12. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16571.mxf" ! decodebin name=d13 d13. ! queue ! video/x-raw ! c_v. d13. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17301.mxf" ! decodebin name=d14 d14. ! queue ! video/x-raw ! c_v. d14. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17098.mxf" ! decodebin name=d15 d15. ! queue ! video/x-raw ! c_v. d15. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/ABC821744.mxf" ! decodebin name=d16 d16. ! queue ! video/x-raw ! c_v. d16. ! queue ! audio/x-raw ! c_a1.
#
#
#
# c_v. ! sync. sync. ! videoconvert ! videoscale ! video/x-raw,width=720,height=576 ! identity single-segment=true silent=false !
#
#   avenc_mpeg2video bitrate=3096000 ! video/mpeg,mpegversion=2 ! mpegvideoparse ! q.sink_1 q.src_1 ! mux.sink_1401
#
# c_a1. ! sync. sync. ! audioconvert ! audio/x-raw,channels=2 ! audioresample ! identity single-segment=true !
#
# avenc_mp2 bitrate=192000 ! mpegaudioparse ! tee name=t
#
#   t.src_0 ! q.sink_2 q.src_2 ! mux.sink_1461
#
#   t.src_1 ! q.sink_3 q.src_3 ! mux.sink_1462
#
#   t.src_2 ! q.sink_4 q.src_4 ! mux.sink_1463
#
#   t.src_3 ! q.sink_5 q.src_5 ! mux.sink_1464
#
#   t.src_4 ! q.sink_6 q.src_6 ! mux.sink_1465
#
# fakesrc num-buffers=1 sizetype=2 sizemax=5 ! application/x-teletext ! q.sink_8 q.sink_8 ! mux.sink_1490
#
# mux.src ! tsparse parse-private-sections=true name=p p.program_30633 !
#
# multifilesink location=/ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_%05d.ts
#
#   next-file=3 max-files=0 max-file-size=0 post-messages=true
#
#  [in ./utils/encode_nicktoons.py:215]
#
# 2019-11-07 12:50:04,286 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00000.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:06,482 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00001.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:08,798 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00002.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:10,938 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00003.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:13,008 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00004.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:15,325 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00005.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:17,602 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00006.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:19,651 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00007.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:21,792 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00008.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:25,068 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00009.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:27,685 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00010.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:29,957 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00011.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:32,136 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00012.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:34,299 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00013.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:36,529 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00014.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:38,750 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00015.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:40,989 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00016.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:43,240 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00017.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:45,371 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00018.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:48,801 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00019.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:51,061 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00020.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:53,453 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00021.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:55,663 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00022.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:57,968 INFO: /ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_41/segment_00023.ts finished. [in ./utils/encode_nicktoons.py:135]
#
# 2019-11-07 12:50:58,104 ERROR: Error: gst-stream-error-quark: Internal data stream error. (1): mxfdemux.c(3257): gst_mxf_demux_loop (): /GstPipeline:pipeline40/GstDecodeBin:d16/GstMXFDemux:mxfdemux754:
#
# streaming stopped, reason error (-5)
#
#  [in ./utils/encode_nicktoons.py:128]
#
# 2019-11-07 12:50:58,105 INFO: Setting pipline to NULL. [in ./utils/encode_nicktoons.py:156]
#
# 2019-11-07 12:50:58,177 INFO: Nick Romania - 2019-11-07 converting break:42 [in ./utils/encode_nicktoons.py:214]
#
# 2019-11-07 12:50:58,177 INFO:
#
# concat name=c_v adjust-base=false
#
# concat name=c_a1 adjust-base=false
#
# mpegtsmux name=mux prog-map=program_map,PCR_30633=sink_1401,sink_1401=30633,sink_1461=30633,sink_1462=30633,sink_1463=30633,sink_1464=30633,sink_1465=30633,sink_1490=30633,PMT_30633=1402
#
# multiqueue name=q max-size-buffers=23 max-size-bytes=0 max-size-time=0 sync-by-running-time=TRUE
#
# streamsynchronizer name=sync
#
# filesrc location="/ddrive/commercials/ABC821739.mxf" ! decodebin name=d0 d0. ! queue ! video/x-raw ! c_v. d0. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO12519.mxf" ! decodebin name=d1 d1. ! queue ! video/x-raw ! c_v. d1. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16876.mxf" ! decodebin name=d2 d2. ! queue ! video/x-raw ! c_v. d2. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16658.mxf" ! decodebin name=d3 d3. ! queue ! video/x-raw ! c_v. d3. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16506.mxf" ! decodebin name=d4 d4. ! queue ! video/x-raw ! c_v. d4. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16369.mxf" ! decodebin name=d5 d5. ! queue ! video/x-raw ! c_v. d5. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO14560.mxf" ! decodebin name=d6 d6. ! queue ! video/x-raw ! c_v. d6. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16913.mxf" ! decodebin name=d7 d7. ! queue ! video/x-raw ! c_v. d7. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17098.mxf" ! decodebin name=d8 d8. ! queue ! video/x-raw ! c_v. d8. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO15448.mxf" ! decodebin name=d9 d9. ! queue ! video/x-raw ! c_v. d9. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17243.mxf" ! decodebin name=d10 d10. ! queue ! video/x-raw ! c_v. d10. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17009.mxf" ! decodebin name=d11 d11. ! queue ! video/x-raw ! c_v. d11. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17261.mxf" ! decodebin name=d12 d12. ! queue ! video/x-raw ! c_v. d12. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO16594.mxf" ! decodebin name=d13 d13. ! queue ! video/x-raw ! c_v. d13. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO15645.mxf" ! decodebin name=d14 d14. ! queue ! video/x-raw ! c_v. d14. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO14511.mxf" ! decodebin name=d15 d15. ! queue ! video/x-raw ! c_v. d15. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/RO17068.mxf" ! decodebin name=d16 d16. ! queue ! video/x-raw ! c_v. d16. ! queue ! audio/x-raw ! c_a1.
#
# filesrc location="/ddrive/commercials/ABC821747.mxf" ! decodebin name=d17 d17. ! queue ! video/x-raw ! c_v. d17. ! queue ! audio/x-raw ! c_a1.
#
#
#
# c_v. ! sync. sync. ! videoconvert ! videoscale ! video/x-raw,width=720,height=576 ! identity single-segment=true silent=false !
#
#   avenc_mpeg2video bitrate=3096000 ! video/mpeg,mpegversion=2 ! mpegvideoparse ! q.sink_1 q.src_1 ! mux.sink_1401
#
# c_a1. ! sync. sync. ! audioconvert ! audio/x-raw,channels=2 ! audioresample ! identity single-segment=true !
#
# avenc_mp2 bitrate=192000 ! mpegaudioparse ! tee name=t
#
#   t.src_0 ! q.sink_2 q.src_2 ! mux.sink_1461
#
#   t.src_1 ! q.sink_3 q.src_3 ! mux.sink_1462
#
#   t.src_2 ! q.sink_4 q.src_4 ! mux.sink_1463
#
#   t.src_3 ! q.sink_5 q.src_5 ! mux.sink_1464
#
#   t.src_4 ! q.sink_6 q.src_6 ! mux.sink_1465
#
# fakesrc num-buffers=1 sizetype=2 sizemax=5 ! application/x-teletext ! q.sink_8 q.sink_8 ! mux.sink_1490
#
# mux.src ! tsparse parse-private-sections=true name=p p.program_30633 !
#
# multifilesink location=/ddrive/streams/nick_rom/commercials/playlists/2019-11-07/brk_42/segment_%05d.ts
#
#   next-file=3 max-files=0 max-file-size=0 post-messages=true
#
#  [in ./utils/encode_nicktoons.py:215]
#
# 2019-11-07 12:50:58,239 ERROR: Error: gst-stream-error-quark: Internal data stream error. (1): mxfdemux.c(3257): gst_mxf_demux_loop (): /GstPipeline:pipeline41/GstDecodeBin:d17/GstMXFDemux:mxfdemux770:
#
# streaming stopped, reason error (-5)
#
#  [in ./utils/encode_nicktoons.py:128]
#
# 2019-11-07 12:50:58,239 INFO: Setting pipline to NULL. [in ./utils/encode_nicktoons.py:156]
