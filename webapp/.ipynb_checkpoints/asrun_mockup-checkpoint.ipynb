# %%
from config import Config
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas
import os
import m3u8
from datetime import datetime
from datetime import timedelta
import re
import copy
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

channel="nicktoons_bul"
txdate="2019-11-10"

# %%
def get_commercial_log(channel,txdate):
    breaks=[]
    local_feed=[lf for lf in Config.LOCALIZED_FEEDS if lf["dir"]==channel][0]
    xls_filename=os.path.join(Config.STREAMS_ROOT,local_feed["dir"],"commercials","playlists",
                          txdate,txdate+"_"+local_feed["log"]+".xls")
    df=pandas.read_excel(xls_filename)
    for b in df["Break Number"].unique():
        com_break={}
        com_break["id"]=b
        com_break["starttime"]=df[df["Break Number"] == b].iloc[0]["Start Time"][0:-3]
        com_break["duration"]='{:02d}:{:02d}'.format(int(df[df["Break Number"] == b]["Duartion WORK"].sum()/60),
                                             df[df["Break Number"] == b]["Duartion WORK"].sum()%60)
        if os.path.isfile(os.path.join(Config.STREAMS_ROOT,local_feed["dir"],"commercials","playlists",
                                           txdate,'brk_{:02d}'.format(b),"playlist.m3u8")):
            com_break["manifest"]=os.path.join(Config.BASE_URI,local_feed["dir"],"commercials","playlists",
                                           txdate,'brk_{:02d}'.format(b),"playlist.m3u8")
            com_break["segments"]=[]
            for segment in m3u8.load(com_break["manifest"]).segments:
                com_break["segments"].append(segment.uri)
        breaks.append(com_break)
    return breaks

# %%
def ts_to_datetime(ts):
    (hour,min,sec)=ts.split(':')
    return datetime(1900,1,int(int(hour)/24)+1,int(hour)%24,int(min),int(sec.split('.')[0]),int(sec.split('.')[1]))

def ts_to_timedelta(ts):
    (hour,min,sec)=ts.split(':')
    return timedelta(hours=int(hour),minutes=int(min),seconds=int(sec.split('.')[0]),microseconds=int(sec.split('.')[1]))

def get_segments_played(channel,txdate):
    downloads=[]
    parse_packets=[]
    regex_download=r"([^\s]*)(.*)(http:.*)"
    regex_timestamp=r"([^\s]*).*Pushing out pending packets at: ([^\s]*) ([^\s]*).*Timestamp:([^\s]*) DUR:([^\s]*) SIZE:([^\s]*)"
    hls2rtp_logs="/ddrive/ottstreamer/hls2rtp/logs"
    local_feed=[lf for lf in Config.LOCALIZED_FEEDS if lf["dir"]==channel][0]
    txdate_datetime=datetime.strptime(txdate,'%Y-%m-%d')
    if txdate_datetime.date()==datetime.now().date():
        hls2rtp_log=os.path.join(hls2rtp_logs,"hls2rtp_"+local_feed["dir"]+".log")
    else:
        hls2rtp_log=os.path.join(hls2rtp_logs,"hls2rtp_"+local_feed["dir"]+".log-"+txdate_datetime.strftime('%Y%m%d'))

    base_wallclock=datetime(1900, 1, 1, 0, 0)
    base_timestamp=datetime(1900, 1, 1, 0, 0)
    prev_end_timestamp=datetime(1900, 1, 1, 0, 0)
    prev_end_timestamp_tp=datetime(1900,1,1,0,0)
    download={}
    with open(hls2rtp_log) as file:
        for ln,line in enumerate(file):
            if "Pushing out pending packets at:" in line:
                parse_packet={}
                if line.find("percent. ") > 0:
                    line=line[line.find("percent. ")+9:]
                match=re.search(regex_timestamp,line)
                base_timestamp=ts_to_datetime(match.group(1)[0:-3])
                base_wallclock=datetime.strptime(match.group(2) +" " + match.group(3),"%Y-%m-%d %H:%M:%S.%f")
                parse_packet["linenumber"]=ln
                parse_packet["wallclock"]=datetime.strptime(match.group(2) +" " + match.group(3),"%Y-%m-%d %H:%M:%S.%f")
                parse_packet["timestamp"]=ts_to_datetime(match.group(1)[0:-3])
                parse_packet["PCR"]=ts_to_datetime(match.group(4)[0:-3])
                parse_packet["Duration"]=ts_to_timedelta(match.group(5)[0:-3])
                parse_packet["Size"]=int(match.group(6))
                parse_packet["gap"]=parse_packet["timestamp"]-prev_end_timestamp_tp
                prev_end_timestamp_tp=parse_packet["timestamp"]+parse_packet["Duration"]
                parse_packets.append(parse_packet)
                

            elif "Downloading fragment uri" in line:
                match=re.search(regex_download,line)
                download={}
                download["gap"]=ts_to_datetime(match.group(1)[0:-3])-prev_end_timestamp
                download["start_linenumber"]=ln
                download["start_timestamp"]=ts_to_datetime(match.group(1)[0:-3])
                download["start_wallclock"]=base_wallclock+(download["start_timestamp"]-base_timestamp)
                download["url"]=match.group(3).split(' ')[0][0:-1]
            elif "fragment download finished" in line:
                match=re.search(regex_download,line)
                download["end_linenumber"]=ln
                download["end_timestamp"]=ts_to_datetime(match.group(1)[0:-3])
                prev_end_timestamp=download["end_timestamp"]
                download["end_wallclock"]=base_wallclock+(download["end_timestamp"]-base_timestamp)
                download["result"]=match.group(3).split(' ')[1]
                download["result2"]=match.group(3).split(' ')[2]
                if "start_wallclock" in download:
                    downloads.append(download)
    return downloads,parse_packets

# %%
#  ar: TS segments downloaded over the day
#  tp: Packets sent by tsparse over the day
cl=get_commercial_log(channel,txdate)
ar,tp=get_segments_played(channel,txdate)

# %%
#As-run log of commecial breaks...
for brk in cl:
    try:
        com_fragments=[]
        for segment in brk["segments"]:
            com_fragments.append([a["url"] for a in ar].index(segment))
        print('Break {} scheduled for {} is played at {} with duration:{}.'.
              format(brk["id"],brk["starttime"],ar[com_fragments[0]]["start_wallclock"].strftime('%H:%M:%S'),
                    (ar[com_fragments[-1]]["end_wallclock"]-ar[com_fragments[0]]["start_wallclock"])))
    except:
        print('Break {} scheduled for {} is not played.'.format(brk["id"],brk["starttime"]))
# Out:
# Break 1 scheduled for 06:04:00 is played at 06:05:16 with duration:0:06:02.262273.
# Break 2 scheduled for 06:34:00 is played at 06:33:46 with duration:0:05:31.067698.
# Break 3 scheduled for 07:02:00 is played at 07:02:56 with duration:0:05:36.750595.
# Break 4 scheduled for 07:29:00 is played at 07:32:52 with duration:0:06:04.691042.
# Break 5 scheduled for 08:21:00 is played at 08:17:05 with duration:0:05:40.111931.
# Break 6 scheduled for 08:48:00 is played at 08:46:05 with duration:0:06:08.536499.
# Break 7 scheduled for 09:07:00 is played at 09:05:45 with duration:0:05:29.994211.
# Break 8 scheduled for 09:34:00 is played at 09:33:14 with duration:0:06:00.878653.
# Break 9 scheduled for 10:23:00 is played at 10:24:24 with duration:0:06:09.184967.
# Break 10 scheduled for 10:52:00 is played at 10:54:20 with duration:0:05:33.749871.
# Break 11 scheduled for 11:19:00 is played at 11:23:30 with duration:0:05:24.112974.
# Break 12 scheduled for 11:48:00 is played at 11:41:39 with duration:0:06:06.208664.
# Break 13 scheduled for 12:16:00 is played at 12:12:28 with duration:0:06:05.065649.
# Break 14 scheduled for 12:44:00 is played at 12:41:24 with duration:0:05:36.668460.
# Break 15 scheduled for 13:12:00 is played at 13:11:20 with duration:0:06:14.645299.
# Break 16 scheduled for 13:41:00 is played at 13:40:52 with duration:0:05:27.551000.
# Break 17 scheduled for 14:11:00 is played at 14:10:02 with duration:0:05:38.269930.
# Break 18 scheduled for 14:39:00 is played at 14:39:12 with duration:0:06:13.676385.
# Break 19 scheduled for 15:10:00 is played at 15:09:09 with duration:0:05:39.563033.
# Break 20 scheduled for 15:48:00 is played at 15:48:32 with duration:0:06:12.928810.
# Break 21 scheduled for 16:16:00 is played at 16:16:40 with duration:0:05:27.559369.
# Break 22 scheduled for 16:44:00 is played at 16:44:57 with duration:0:06:05.649976.
# Break 23 scheduled for 17:13:00 is played at 17:13:51 with duration:0:06:09.615422.
# Break 24 scheduled for 17:40:00 is played at 17:42:29 with duration:0:05:25.470249.
# Break 25 scheduled for 18:09:00 is not played.
# Break 26 scheduled for 18:37:00 is not played.
# Break 27 scheduled for 19:03:00 is not played.
# Break 28 scheduled for 19:32:00 is not played.
# Break 29 scheduled for 20:23:00 is not played.
# Break 30 scheduled for 20:50:00 is not played.
# Break 31 scheduled for 21:18:00 is not played.
# Break 32 scheduled for 21:44:00 is not played.
# Break 33 scheduled for 22:12:00 is not played.
# Break 34 scheduled for 22:38:00 is not played.
# Break 35 scheduled for 23:05:00 is not played.
# Break 36 scheduled for 23:33:00 is not played.

# %%
start=3500
stop=3800 #len(ar)
print("Total samples:{}".format(stop))
fig,(ax1,ax2,ax3)=plt.subplots(3,1,figsize=(16, 12))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax1.plot([a["start_wallclock"] for a in ar[start:stop]],
            [(a["end_wallclock"]-a["start_wallclock"]).total_seconds() for a in ar[start:stop]]);
ax1.set_ylabel("Segment download time");
#ax2.hist( [(a["end_wallclock"]-a["start_timestamp"]).total_seconds() for a in ar[start:stop]],log=True,bins=100);
ax2.plot( [a["start_wallclock"] for a in ar[start:stop]],
         [(a["start_wallclock"]-a["start_timestamp"]).total_seconds() for a in ar[start:stop]]);
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'));
ax2.set_ylabel("Timestamp jitter");

ax3.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax3.plot([a["start_wallclock"] for a in ar[start:stop]],
            [a["gap"].total_seconds() for a in ar[start:stop]]);
ax3.set_ylabel("Gap between downloads");
# Out:
# Total samples:3800

# %%
# Slow downloads
[a for a in ar if (a["end_wallclock"]-a["start_wallclock"])>timedelta(seconds=25)]
# Out:
# [{'gap': datetime.timedelta(seconds=14, microseconds=926749),
#   'start_linenumber': 14110,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 13, 57, 7, 840833),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 0, 20, 47, 218909),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_187836.ts',
#   'end_linenumber': 14340,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 13, 57, 36, 377496),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 0, 21, 15, 755583),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=15, microseconds=805319),
#   'start_linenumber': 16542,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 14, 0, 12, 26232),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 0, 23, 51, 404328),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_187848.ts',
#   'end_linenumber': 16773,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 14, 0, 39, 807421),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 0, 24, 19, 185519),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=13, microseconds=324258),
#   'start_linenumber': 25389,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 14, 12, 51, 810885),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 0, 36, 31, 188977),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_187898.ts',
#   'end_linenumber': 25562,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 14, 13, 16, 971980),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 0, 36, 56, 350073),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=14, microseconds=529980),
#   'start_linenumber': 27703,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 14, 16, 42, 46846),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 0, 40, 21, 424943),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_187913.ts',
#   'end_linenumber': 27892,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 14, 17, 8, 600134),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 0, 40, 47, 978228),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=15, microseconds=16),
#   'start_linenumber': 28341,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 14, 17, 28, 94583),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 0, 41, 7, 472686),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_187916.ts',
#   'end_linenumber': 28515,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 14, 17, 54, 306540),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 0, 41, 33, 684629),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=15, microseconds=924196),
#   'start_linenumber': 30632,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 14, 20, 32, 286425),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 0, 44, 11, 664522),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_187928.ts',
#   'end_linenumber': 30757,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 14, 20, 57, 911727),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 0, 44, 37, 289812),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=15, microseconds=732879),
#   'start_linenumber': 32338,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 14, 22, 50, 429801),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 0, 46, 29, 807897),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_187937.ts',
#   'end_linenumber': 32514,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 14, 23, 16, 756004),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 0, 46, 56, 134100),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=15, microseconds=654085),
#   'start_linenumber': 45194,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 14, 40, 52, 540227),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 1, 4, 31, 918325),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188008.ts',
#   'end_linenumber': 45384,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 14, 41, 20, 489909),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 1, 4, 59, 867993),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=16, microseconds=231533),
#   'start_linenumber': 46205,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 14, 42, 24, 634448),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 1, 6, 4, 12539),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188014.ts',
#   'end_linenumber': 46409,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 14, 42, 50, 248443),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 1, 6, 29, 626542),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=9, microseconds=895606),
#   'start_linenumber': 48717,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 14, 45, 51, 850403),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 1, 9, 31, 228488),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188028.ts',
#   'end_linenumber': 48842,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 14, 46, 16, 879501),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 1, 9, 56, 257579),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=12, microseconds=311353),
#   'start_linenumber': 52905,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 14, 52, 0, 226574),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 1, 15, 39, 604664),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188052.ts',
#   'end_linenumber': 53093,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 14, 52, 27, 934041),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 1, 16, 7, 312133),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=14, microseconds=202634),
#   'start_linenumber': 57557,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 14, 58, 8, 602408),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 1, 21, 47, 980494),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188076.ts',
#   'end_linenumber': 57770,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 14, 58, 33, 840488),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 1, 22, 13, 218584),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=11, microseconds=612531),
#   'start_linenumber': 64078,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 15, 6, 58, 151212),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 1, 30, 37, 529303),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188111.ts',
#   'end_linenumber': 64246,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 15, 7, 23, 313432),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 1, 31, 2, 691524),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=12, microseconds=613991),
#   'start_linenumber': 65908,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 15, 9, 16, 295573),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 1, 32, 55, 673653),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188120.ts',
#   'end_linenumber': 66036,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 15, 9, 44, 1818),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 1, 33, 23, 379906),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=14, microseconds=892897),
#   'start_linenumber': 72514,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 15, 19, 14, 902341),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 1, 42, 54, 280437),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188159.ts',
#   'end_linenumber': 72689,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 15, 19, 41, 880715),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 1, 43, 21, 811948),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=11, microseconds=353727),
#   'start_linenumber': 79366,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 15, 29, 36, 546458),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 1, 53, 15, 924546),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188200.ts',
#   'end_linenumber': 79556,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 15, 30, 3, 177202),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 1, 53, 42, 555285),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=12, microseconds=637010),
#   'start_linenumber': 82044,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 15, 33, 26, 782480),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 1, 57, 6, 160575),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188215.ts',
#   'end_linenumber': 82168,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 15, 33, 52, 419084),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 1, 57, 31, 797173),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=14, microseconds=109281),
#   'start_linenumber': 83457,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 15, 35, 44, 922573),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 1, 59, 24, 300664),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188224.ts',
#   'end_linenumber': 83584,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 15, 36, 10, 557745),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 1, 59, 49, 935836),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=15, microseconds=924506),
#   'start_linenumber': 85157,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 15, 38, 3, 66575),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 2, 1, 42, 444673),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188233.ts',
#   'end_linenumber': 85349,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 15, 38, 30, 498639),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 2, 2, 9, 876732),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=11, microseconds=250955),
#   'start_linenumber': 90618,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 15, 45, 20, 522743),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 2, 8, 59, 900835),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188262.ts',
#   'end_linenumber': 90793,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 15, 45, 46, 449064),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 2, 9, 25, 827150),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=14, microseconds=376168),
#   'start_linenumber': 93988,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 15, 49, 56, 802428),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 2, 13, 36, 180514),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188280.ts',
#   'end_linenumber': 94114,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 15, 50, 24, 832236),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 2, 14, 4, 210325),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=15, microseconds=108821),
#   'start_linenumber': 98072,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 15, 56, 5, 182525),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 2, 19, 44, 560620),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188304.ts',
#   'end_linenumber': 98267,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 15, 56, 31, 356398),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 2, 20, 10, 734486),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=16, microseconds=207267),
#   'start_linenumber': 99225,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 15, 57, 37, 278551),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 2, 21, 16, 656633),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188310.ts',
#   'end_linenumber': 99411,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 15, 58, 2, 660007),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 2, 21, 42, 371515),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=13, microseconds=30670),
#   'start_linenumber': 108686,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 16, 11, 3, 114566),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 2, 34, 42, 492661),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188363.ts',
#   'end_linenumber': 108867,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 16, 11, 28, 157506),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 2, 35, 7, 535596),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=13, microseconds=518332),
#   'start_linenumber': 109854,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 16, 12, 35, 210446),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 2, 36, 14, 588525),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188369.ts',
#   'end_linenumber': 110045,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 16, 13, 0, 995365),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 2, 36, 40, 373454),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=13, microseconds=743451),
#   'start_linenumber': 113556,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 16, 17, 57, 542812),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 2, 41, 36, 920913),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188390.ts',
#   'end_linenumber': 113733,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 16, 18, 23, 924214),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 2, 42, 3, 302295),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=14, microseconds=585851),
#   'start_linenumber': 115845,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 16, 21, 1, 730479),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 2, 44, 41, 108571),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188402.ts',
#   'end_linenumber': 116028,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 16, 21, 26, 994243),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 2, 45, 6, 372344),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=15, microseconds=879526),
#   'start_linenumber': 118060,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 16, 24, 5, 922500),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 2, 47, 45, 300583),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188414.ts',
#   'end_linenumber': 118238,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 16, 24, 32, 168040),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 2, 48, 11, 546126),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=11, microseconds=994933),
#   'start_linenumber': 125511,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 16, 33, 41, 522720),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 2, 57, 20, 900813),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188452.ts',
#   'end_linenumber': 125733,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 16, 34, 7, 992826),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 2, 57, 47, 370914),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=12, microseconds=448203),
#   'start_linenumber': 127449,
#   'start_timestamp': datetime.datetime(1900, 1, 2, 16, 35, 59, 666624),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 2, 59, 39, 44707),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_188461.ts',
#   'end_linenumber': 127641,
#   'end_timestamp': datetime.datetime(1900, 1, 2, 16, 36, 28, 919540),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 3, 0, 8, 297635),
#   'result': '0',
#   'result2': 'ok'},
#  {'gap': datetime.timedelta(seconds=12, microseconds=592676),
#   'start_linenumber': 493951,
#   'start_timestamp': datetime.datetime(1900, 1, 3, 0, 39, 30, 460352),
#   'start_wallclock': datetime.datetime(2019, 11, 10, 11, 3, 9, 838432),
#   'url': 'http://129.228.120.86/streams/nicktoons_pol/segment_190363.ts',
#   'end_linenumber': 494141,
#   'end_timestamp': datetime.datetime(1900, 1, 3, 0, 39, 56, 749017),
#   'end_wallclock': datetime.datetime(2019, 11, 10, 11, 3, 36, 127118),
#   'result': '0',
#   'result2': 'ok'}]

# %%
#tsparse packet durations...
tp_start=120000
tp_end=121000 #len(tp)
print("Total number of packets:{}".format(tp_end))
fig,(ax1,ax2,ax3,ax4)=plt.subplots(4,1,figsize=(16,12))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax1.plot([t["wallclock"] for t in tp[tp_start:tp_end]],[t["Duration"].total_seconds() for t in tp[tp_start:tp_end]],"bp",markersize=1)
ax1.set_ylabel("TSParse packet duration");
ax2.hist( [t["Duration"].total_seconds() for t in tp[tp_start:tp_end]],log=True,bins=100);
ax2.set_xlabel("TSParse packet duration");
ax3.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax3.plot([t["wallclock"] for t in tp[tp_start:tp_end]],[t["gap"].total_seconds() for t in tp[tp_start:tp_end]],"bp",markersize=1);
ax3.set_ylabel("Gaps between packets");
ax4.hist( [t["gap"].total_seconds() for t in tp[tp_start:tp_end]],log=True,bins=100);
ax4.set_xlabel("Gaps between packets");
# Out:
# Total number of packets:121000

# %%
#TSParse packets with 0 duration
[t for t in tp if t["Duration"].total_seconds()==0]
# Out:
# []

# %%
[t["gap"].total_seconds() for t in tp ]
# Out:
# [135466.792985,
#  -0.335703,
#  -0.01863,
#  -0.043231,
#  -0.073247,
#  -0.000254,
#  0.071935,
#  0.104227,
#  0.170847,
#  0.168829,
#  0.130479,
#  0.010985,
#  -0.02729,
#  -0.064453,
#  -0.033907,
#  0.015969,
#  0.052296,
#  -0.288482,
#  -0.380856,
#  -0.563197,
#  -0.420008,
#  -0.642964,
#  -0.532331,
#  -0.368682,
#  -0.274993,
#  -0.405324,
#  -0.456725,
#  -0.435659,
#  -0.39588,
#  -0.29216,
#  -0.423383,
#  -0.814242,
#  -0.460849,
#  -0.414552,
#  -0.262401,
#  -0.359596,
#  -0.533114,
#  -0.402934,
#  -0.259485,
#  -0.44449,
#  -0.672976,
#  -0.250646,
#  -0.427312,
#  -0.236644,
#  -0.223752,
#  -0.124591,
#  -0.350568,
#  -0.614308,
#  -0.600697,
#  -0.426238,
#  -0.839089,
#  -0.439024,
#  -0.696369,
#  -0.448866,
#  -0.364013,
#  -0.31491,
#  -0.629795,
#  -1.137716,
#  -0.548932,
#  -0.448106,
#  -0.363141,
#  -0.661103,
#  -0.494073,
#  -0.314349,
#  1.544615,
#  -0.533144,
#  -0.373724,
#  -0.313346,
#  -0.294666,
#  -0.400826,
#  -0.478923,
#  -0.52445,
#  -0.594069,
#  -0.234595,
#  -0.325728,
#  -0.19163,
#  -0.50027,
#  -0.436829,
#  -0.499738,
#  -0.397792,
#  0.001529,
#  -0.001738,
#  0.004824,
#  -0.002323,
#  -0.001019,
#  -0.001919,
#  9e-06,
#  -0.003336,
#  0.000622,
#  0.003032,
#  0.004297,
#  -0.006774,
#  0.00401,
#  0.00445,
#  -0.003656,
#  -0.000948,
#  -0.000591,
#  -0.002596,
#  0.002554,
#  13.673156,
#  12.017372,
#  0.275649,
#  0.150656,
#  0.1051,
#  0.189541,
#  0.102589,
#  0.042897,
#  0.010425,
#  -0.06714,
#  -0.072747,
#  -0.117052,
#  -0.04495,
#  -0.054608,
#  -0.113283,
#  -0.126048,
#  -0.517632,
#  -0.541662,
#  -0.498716,
#  -0.564524,
#  -0.37138,
#  -0.312641,
#  -0.448433,
#  -0.508254,
#  -0.580936,
#  -0.532517,
#  -0.608565,
#  -0.537258,
#  -0.378319,
#  -0.395192,
#  -0.415668,
#  -0.326184,
#  -0.356342,
#  -0.299528,
#  -0.230105,
#  -0.547673,
#  -0.338158,
#  -0.680479,
#  -0.531392,
#  -0.628933,
#  -0.573294,
#  -0.603405,
#  -0.221464,
#  -0.270954,
#  -0.538128,
#  -0.371962,
#  -0.630158,
#  -0.360738,
#  -0.534717,
#  -0.465522,
#  -0.74614,
#  -0.334492,
#  -0.524664,
#  -0.49639,
#  -0.450448,
#  -0.433451,
#  -0.442963,
#  -0.546994,
#  -0.475191,
#  -0.399237,
#  -0.412587,
#  -0.571443,
#  -0.416424,
#  -0.477633,
#  -0.468845,
#  -0.51182,
#  4.175313,
#  -0.489603,
#  -0.393175,
#  -0.415679,
#  -0.472286,
#  -0.695666,
#  -0.587473,
#  -0.434516,
#  -0.36405,
#  -0.334883,
#  -0.563312,
#  -0.544302,
#  -0.616763,
#  -0.468791,
#  -0.333563,
#  -0.003628,
#  0.002483,
#  -0.004302,
#  0.00041,
#  0.001759,
#  -0.00229,
#  0.000618,
#  0.000461,
#  0.003617,
#  0.001874,
#  -0.00558,
#  0.002437,
#  -0.002297,
#  0.000912,
#  -0.00406,
#  0.0011,
#  0.000369,
#  0.001157,
#  14.374777,
#  13.207508,
#  -0.098528,
#  -0.02166,
#  -0.013366,
#  -0.076027,
#  -0.17701,
#  -0.180054,
#  -0.057524,
#  0.024839,
#  0.013772,
#  0.017941,
#  -0.106097,
#  -0.127391,
#  -0.109892,
#  -0.097048,
#  -0.101815,
#  -0.306918,
#  -0.090737,
#  0.084806,
#  0.130415,
#  0.080106,
#  -0.615454,
#  -0.659175,
#  -0.620276,
#  -0.7045,
#  -0.442938,
#  -0.447597,
#  -0.46875,
#  -0.475132,
#  -0.475095,
#  -0.508944,
#  -0.505384,
#  -0.399787,
#  -0.278553,
#  -0.635598,
#  -0.39101,
#  -0.388596,
#  -0.520634,
#  -0.27658,
#  -0.154364,
#  -0.229474,
#  -0.333131,
#  -0.271071,
#  -0.580498,
#  -0.640368,
#  -0.942417,
#  -1.026679,
#  -0.711448,
#  -0.197263,
#  -0.349045,
#  -0.287405,
#  -0.311475,
#  -0.32874,
#  -0.450791,
#  -0.483416,
#  -0.466832,
#  -0.575378,
#  -0.683543,
#  -0.433626,
#  -0.528578,
#  -0.361969,
#  -0.704407,
#  0.458352,
#  -0.568828,
#  -0.435482,
#  -0.536887,
#  -0.455703,
#  -0.474758,
#  -0.197802,
#  -0.291615,
#  -0.660121,
#  -0.327972,
#  -0.512255,
#  -0.416783,
#  -0.411853,
#  -0.470344,
#  -0.424693,
#  -0.7173,
#  -0.060666,
#  0.19898,
#  -0.196619,
#  0.003848,
#  -0.007928,
#  0.003972,
#  0.000128,
#  -0.000449,
#  -0.003428,
#  -0.001669,
#  0.003625,
#  -0.001751,
#  0.006143,
#  -0.00694,
#  -0.000361,
#  0.000701,
#  0.001817,
#  -0.001971,
#  14.707892,
#  11.420408,
#  -0.240046,
#  -0.008017,
#  0.057366,
#  0.076918,
#  0.052704,
#  -0.000104,
#  -0.127357,
#  -0.010157,
#  0.031687,
#  -0.204226,
#  -0.165837,
#  -0.215238,
#  -0.802302,
#  -0.240467,
#  -0.249773,
#  -0.100826,
#  -0.125083,
#  -0.261899,
#  -0.28421,
#  -0.541617,
#  -0.670657,
#  -0.804061,
#  -0.717862,
#  -0.558834,
#  -0.407657,
#  -0.514903,
#  -0.324739,
#  -0.402442,
#  -0.615133,
#  -0.293615,
#  -0.322606,
#  -0.497037,
#  -0.506911,
#  -0.34008,
#  -0.411391,
#  -0.397071,
#  -0.326983,
#  -0.61225,
#  -0.680349,
#  -0.392122,
#  -0.438603,
#  -0.28548,
#  -0.449826,
#  -0.777292,
#  -0.476967,
#  -0.55921,
#  -0.444443,
#  -0.498273,
#  -0.35859,
#  -0.241816,
#  -0.38335,
#  -0.439197,
#  -0.511821,
#  -0.474969,
#  -0.411013,
#  -0.417046,
#  -0.313755,
#  -0.458347,
#  -0.523352,
#  -0.461707,
#  -0.403992,
#  -0.356889,
#  -0.396255,
#  -0.537696,
#  4.672003,
#  -0.632488,
#  -0.340232,
#  -0.315712,
#  -0.648349,
#  -0.89206,
#  -0.394033,
#  -0.33034,
#  -0.721602,
#  -0.984825,
#  -0.582993,
#  -0.205465,
#  -0.182389,
#  -0.319437,
#  -0.422686,
#  -0.046342,
#  -0.002111,
#  -0.002914,
#  0.002457,
#  0.000793,
#  -0.004111,
#  0.000711,
#  0.004597,
#  -0.001711,
#  -0.000791,
#  -0.000987,
#  -0.002235,
#  0.002925,
#  -0.000573,
#  0.003121,
#  -0.004398,
#  14.511787,
#  13.188535,
#  -0.008156,
#  -1.194296,
#  -0.123502,
#  0.027429,
#  0.028801,
#  0.835222,
#  0.445305,
#  0.015563,
#  -0.062635,
#  -0.078614,
#  -0.095128,
#  -0.096057,
#  -0.036759,
#  -0.03077,
#  0.033931,
#  0.118369,
#  0.022163,
#  -0.676342,
#  -0.489794,
#  -0.506697,
#  -0.510205,
#  -0.625414,
#  -0.310401,
#  -0.393372,
#  -0.374513,
#  -0.445776,
#  -0.470158,
#  -0.562795,
#  -0.411054,
#  -0.546714,
#  -0.331686,
#  -0.111976,
#  -0.375152,
#  -0.604741,
#  -0.440169,
#  -0.272674,
#  -0.411447,
#  -0.557646,
#  -0.531226,
#  -0.314159,
#  -0.43104,
#  -0.398135,
#  -0.422866,
#  -0.296007,
#  -0.487643,
#  -0.46472,
#  -0.338502,
#  -0.638218,
#  -0.569494,
#  -0.735669,
#  -0.867776,
#  -0.364261,
#  -0.511244,
#  -0.385277,
#  -0.386003,
#  -0.607775,
#  -0.56231,
#  -0.470476,
#  -0.487414,
#  -0.306642,
#  -0.23711,
#  -0.199255,
#  -0.315658,
#  -0.370106,
#  -1.384388,
#  -0.670714,
#  -0.562707,
#  -0.523174,
#  -0.496599,
#  -0.600891,
#  -0.460838,
#  -0.586255,
#  -0.441131,
#  -0.362361,
#  -0.280349,
#  -0.002037,
#  0.002038,
#  -0.000236,
#  -0.000804,
#  -0.001972,
#  -0.000986,
#  0.000196,
#  0.00168,
#  0.000242,
#  -0.00037,
#  0.001125,
#  -0.000246,
#  -0.00285,
#  0.000844,
#  0.000571,
#  -0.000833,
#  15.119345,
#  10.961888,
#  -0.096126,
#  -0.037669,
#  -0.317436,
#  -0.143455,
#  -0.199814,
#  -0.048417,
#  -0.025872,
#  -0.024556,
#  0.023605,
#  0.041184,
#  0.150981,
#  0.083629,
#  0.006092,
#  -0.009259,
#  0.016937,
#  -0.048512,
#  -0.142544,
#  -0.097848,
#  0.104579,
#  0.139442,
#  0.115838,
#  0.151327,
#  -0.070258,
#  -0.613176,
#  -0.848123,
#  -0.588637,
#  -0.513149,
#  -0.503595,
#  -0.510402,
#  -0.460549,
#  -0.43675,
#  -0.435979,
#  -0.379293,
#  -0.278192,
#  -0.220921,
#  -0.217174,
#  -0.500052,
#  -0.724316,
#  -0.818446,
#  -0.546619,
#  -0.513273,
#  -0.385662,
#  -0.263661,
#  -0.311624,
#  -0.176397,
#  -0.301798,
#  -0.56724,
#  -0.518756,
#  -0.429883,
#  -0.352107,
#  -0.395104,
#  -0.539351,
#  -0.501516,
#  -0.591415,
#  -0.447813,
#  -0.772594,
#  -0.235595,
#  -0.335799,
#  -0.456251,
#  -0.286534,
#  -0.417224,
#  -0.607614,
#  -0.407196,
#  0.839009,
#  -1.045911,
#  -0.321362,
#  -0.115304,
#  -0.498272,
#  -0.481198,
#  -0.618662,
#  -0.483572,
#  -0.264788,
#  -0.459292,
#  -0.492549,
#  -0.504751,
#  -0.373272,
#  -0.591389,
#  -0.276852,
#  -0.566019,
#  -0.472959,
#  -0.423451,
#  -0.095812,
#  0.003896,
#  0.007373,
#  -0.008726,
#  3.6e-05,
#  -0.001601,
#  0.00163,
#  -0.001671,
#  0.002012,
#  -0.00233,
#  0.001212,
#  0.003806,
#  -0.001582,
#  0.000647,
#  -0.002804,
#  -0.000623,
#  15.473427,
#  11.532209,
#  0.1662,
#  0.090276,
#  0.032428,
#  0.027701,
#  0.008657,
#  -0.05628,
#  -0.178896,
#  -0.189761,
#  -0.227625,
#  -0.366389,
#  -0.866613,
#  -0.514859,
#  -0.365293,
#  -0.388654,
#  -0.599485,
#  -0.486632,
#  -0.397032,
#  -0.40032,
#  -0.228491,
#  -0.399077,
#  -0.450026,
#  -0.393945,
#  -0.609707,
#  -0.417769,
#  -0.514393,
#  -0.500684,
#  -0.424327,
#  -0.537732,
#  -0.321992,
#  -0.411134,
#  -0.681289,
#  -0.540492,
#  -0.368858,
#  -0.309461,
#  -0.219855,
#  -0.664196,
#  -0.527054,
#  -0.817009,
#  -0.528099,
#  -0.48683,
#  -0.396309,
#  -0.310323,
#  -0.684712,
#  -0.581046,
#  -0.506987,
#  -0.446448,
#  -0.429147,
#  -0.364259,
#  -0.36537,
#  -0.515154,
#  -0.528253,
#  -0.45587,
#  -0.51053,
#  -0.480753,
#  -0.353645,
#  -0.323873,
#  -0.448389,
#  -0.603613,
#  -0.528362,
#  -0.452133,
#  -0.43491,
#  -0.299641,
#  -0.234205,
#  -0.297293,
#  6.2952,
#  -0.277646,
#  -0.345057,
#  -0.517449,
#  -0.729729,
#  -0.51095,
#  -0.579412,
#  -0.553141,
#  -0.201623,
#  -0.447586,
#  -0.658903,
#  -0.697881,
#  -0.415077,
#  -0.443488,
#  -0.629881,
#  -0.671358,
#  -0.003,
#  -0.000762,
#  0.00379,
#  -0.001587,
#  -0.000725,
#  0.0003,
#  0.000169,
#  -0.001387,
#  0.000578,
#  -0.001911,
#  -0.00185,
#  0.005263,
#  -0.00025,
#  -0.003708,
#  -0.001932,
#  0.001554,
#  -9.8e-05,
#  15.442549,
#  13.071366,
#  -0.010298,
#  -0.536214,
#  -0.093717,
#  -0.390981,
#  -0.531321,
#  -0.483605,
#  -0.365702,
#  -0.442941,
#  -0.51053,
#  -0.288457,
#  -0.307445,
#  -0.216851,
#  -0.504064,
#  -0.614737,
#  -0.604049,
#  -0.570072,
#  -0.474684,
#  -0.582688,
#  -0.407621,
#  -0.39633,
#  -0.314232,
#  -0.407117,
#  -0.671828,
#  -0.444684,
#  -0.712213,
#  -0.229969,
#  -0.458462,
#  -0.385174,
#  -0.453809,
#  -0.326292,
#  -0.298393,
#  -0.496981,
#  -0.417321,
#  -0.574025,
#  -0.373268,
#  -0.453625,
#  -0.539077,
#  -0.212126,
#  -0.059512,
#  0.126888,
#  0.330963,
#  0.003761,
#  0.046878,
#  0.092929,
#  0.271757,
#  0.115428,
#  0.102345,
#  0.241235,
#  0.104752,
#  0.020331,
#  0.032381,
#  -0.152283,
#  -0.340803,
#  -0.516971,
#  -0.388969,
#  -0.375925,
#  -0.260369,
#  -0.521549,
#  -0.686987,
#  -0.893429,
#  -0.510561,
#  -0.465374,
#  -0.183465,
#  -0.578889,
#  -0.362791,
#  -0.41961,
#  -0.506378,
#  -0.42128,
#  -0.52184,
#  -0.470173,
#  -0.429966,
#  -0.454908,
#  -0.517535,
#  -0.453801,
#  -0.446468,
#  -0.402688,
#  -0.49016,
#  -0.432602,
#  -0.508794,
#  -0.632185,
#  -0.272731,
#  -0.223498,
#  -4.4e-05,
#  0.003001,
#  -0.001022,
#  -0.001118,
#  0.000783,
#  0.003542,
#  -0.002792,
#  0.00212,
#  -0.002644,
#  -0.000303,
#  0.00135,
#  -0.001262,
#  0.000222,
#  16.370441,
#  10.364655,
#  -0.165917,
#  -0.024779,
#  -0.016406,
#  -0.012222,
#  0.005147,
#  -0.001127,
#  0.000463,
#  -0.086898,
#  -0.060021,
#  -0.004904,
#  -0.04226,
#  -0.063951,
#  -0.018775,
#  -0.072631,
#  0.001322,
#  -0.001482,
#  -0.011404,
#  -0.136902,
#  -0.000292,
#  0.061338,
#  0.16868,
#  0.065695,
#  0.053017,
#  0.117813,
#  0.154327,
#  -0.08229,
#  -0.509456,
#  -0.148896,
#  -0.455458,
#  -0.488836,
#  -0.771602,
#  -0.550747,
#  -0.426192,
#  -0.452792,
#  -0.43439,
#  -0.448517,
#  -0.481691,
#  -0.446554,
#  -0.481422,
#  -0.417988,
#  -0.766772,
#  -0.353248,
#  -0.395319,
#  -0.353647,
#  -0.468959,
#  -0.394401,
#  -0.589802,
#  -0.710745,
#  -0.455374,
#  -0.787876,
#  -0.351805,
#  -0.393006,
#  -0.387633,
#  -0.36991,
#  -0.365336,
#  -0.426211,
#  -0.486643,
#  -0.642096,
#  -0.434896,
#  -0.541395,
#  -0.508747,
#  -0.275698,
#  -0.400133,
#  -0.478723,
#  -0.297774,
#  -0.430465,
#  -1.634163,
#  -0.556636,
#  -0.462192,
#  -0.206781,
#  -0.207365,
#  -0.345625,
#  -0.528082,
#  -1.478406,
#  -0.609563,
#  -0.305207,
#  -0.319774,
#  -0.428588,
#  -0.4377,
#  -0.345305,
#  -0.116717,
#  0.001231,
#  -0.000506,
#  0.005317,
#  -0.002645,
#  0.002022,
#  -0.00439,
#  0.005592,
#  -0.000121,
#  -0.001714,
#  0.002694,
#  -0.000935,
#  16.779846,
#  11.272937,
#  0.003493,
#  0.00424,
#  -0.018645,
#  -0.087073,
#  -0.154242,
#  -0.076381,
#  -0.117142,
#  -0.086042,
#  0.033083,
#  0.083504,
#  -0.165104,
#  -0.40642,
#  -0.36106,
#  -0.354662,
#  -0.284668,
#  -0.684678,
#  -0.424353,
#  -0.648313,
#  -0.449675,
#  -0.356751,
#  -0.44968,
#  -0.380604,
#  -0.489344,
#  -0.301661,
#  -0.423295,
#  -0.529725,
#  -0.669463,
#  -0.49511,
#  -0.218346,
#  -0.396954,
#  -0.660246,
#  -0.916072,
#  -0.491753,
#  -0.512997,
#  -0.368148,
#  -0.445656,
#  -0.361569,
#  -0.334461,
#  -0.554869,
#  -0.407312,
#  -0.474881,
#  -0.494992,
#  -0.485359,
#  -0.432533,
#  -0.520135,
#  -0.484973,
#  -0.481761,
#  -0.52549,
#  -0.439146,
#  -0.515564,
#  -0.363313,
#  -0.250463,
#  -0.18646,
#  -0.452057,
#  -0.424292,
#  -0.630103,
#  -0.598662,
#  -0.786389,
#  -0.349451,
#  -0.234342,
#  -0.533202,
#  -0.626061,
#  -0.576437,
#  -0.420793,
#  6.902487,
#  -0.377032,
#  -0.478409,
#  -0.415294,
#  -0.452705,
#  -0.428933,
#  -0.434568,
#  -0.380701,
#  -0.64388,
#  -0.381261,
#  -0.467886,
#  -0.710393,
#  -0.216152,
#  -0.442948,
#  -0.497105,
#  -0.574544,
#  -0.368013,
#  -0.58801,
#  -0.527516,
#  -0.513242,
#  -0.192391,
#  -0.330372,
#  -0.221973,
#  0.372784,
#  -0.44562,
#  0.000324,
#  -8.1e-05,
#  0.001469,
#  -0.002479,
#  0.001174,
#  0.002523,
#  0.00578,
#  -0.00701,
#  0.001983,
#  -6.1e-05,
#  -0.001563,
#  -0.000937,
#  0.003496,
#  -0.002614,
#  0.004378,
#  -0.004518,
#  -4.9e-05,
#  0.000574,
#  -0.001908,
#  0.001973,
#  -0.002163,
#  0.005556,
#  -0.001629,
#  -0.001687,
#  -0.000504,
#  -0.001614,
#  0.003677,
#  -0.000285,
#  -0.000451,
#  -0.002456,
#  -0.002499,
#  0.001897,
#  0.00206,
#  0.001643,
#  -0.003768,
#  ...]

# %%
#output bitrate..
fig,ax1=plt.subplots(figsize=(16,8))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax1.plot([t["wallclock"]for t in tp if t["Duration"].total_seconds()>0],
         [t["Size"]*8/1000000/t["Duration"].total_seconds() for t in tp if t["Duration"].total_seconds()>0],"bp",markersize=1);
plt.xlabel("time");
plt.ylabel("bitrate");
plt.title("Output bitrate diagram");
plt.grid(True);

# %%
#Packets with duration > 2sec.  Most likely freezed frame..... 
[t for t in tp if t["Duration"]>timedelta(seconds=2)]
# Out:
# []

# %%
#Gap between packets > 1sec.  Most likely freezed frame..... 
[t for t in tp[1:] if t["gap"]>timedelta(seconds=1)]
# Out:
# [{'linenumber': 428,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 1, 36, 232750),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 37, 56, 645202),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 39, 34, 525265),
#   'Duration': datetime.timedelta(microseconds=540351),
#   'Size': 395364,
#   'gap': datetime.timedelta(seconds=1, microseconds=544615)},
#  {'linenumber': 621,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 1, 59, 471620),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 38, 19, 669082),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 39, 49, 975309),
#   'Duration': datetime.timedelta(microseconds=288338),
#   'Size': 229736,
#   'gap': datetime.timedelta(seconds=13, microseconds=673156)},
#  {'linenumber': 625,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 2, 11, 352864),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 38, 31, 974792),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 39, 50, 263647),
#   'Duration': datetime.timedelta(microseconds=539992),
#   'Size': 429016,
#   'gap': datetime.timedelta(seconds=12, microseconds=17372)},
#  {'linenumber': 1096,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 2, 22, 723230),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 38, 42, 694268),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 40, 19, 956366),
#   'Duration': datetime.timedelta(microseconds=496696),
#   'Size': 327872,
#   'gap': datetime.timedelta(seconds=4, microseconds=175313)},
#  {'linenumber': 1238,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 2, 45, 939200),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 39, 5, 715821),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 40, 35, 322179),
#   'Duration': datetime.timedelta(microseconds=518606),
#   'Size': 313960,
#   'gap': datetime.timedelta(seconds=14, microseconds=374777)},
#  {'linenumber': 1242,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 2, 58, 820008),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 39, 19, 441935),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 40, 35, 840786),
#   'Duration': datetime.timedelta(microseconds=416720),
#   'Size': 233308,
#   'gap': datetime.timedelta(seconds=13, microseconds=207508)},
#  {'linenumber': 1883,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 3, 31, 142047),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 39, 51, 763957),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 41, 21, 39682),
#   'Duration': datetime.timedelta(microseconds=791613),
#   'Size': 367728,
#   'gap': datetime.timedelta(seconds=14, microseconds=707892)},
#  {'linenumber': 1887,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 3, 43, 354055),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 40, 3, 975978),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 41, 21, 831295),
#   'Duration': datetime.timedelta(microseconds=607712),
#   'Size': 274856,
#   'gap': datetime.timedelta(seconds=11, microseconds=420408)},
#  {'linenumber': 2332,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 3, 54, 165652),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 40, 14, 787578),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 41, 51, 746001),
#   'Duration': datetime.timedelta(microseconds=634180),
#   'Size': 261508,
#   'gap': datetime.timedelta(seconds=4, microseconds=672003)},
#  {'linenumber': 2487,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 4, 17, 189765),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 40, 37, 811669),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 42, 7, 282498),
#   'Duration': datetime.timedelta(microseconds=452070),
#   'Size': 262824,
#   'gap': datetime.timedelta(seconds=14, microseconds=511787)},
#  {'linenumber': 2491,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 4, 30, 830342),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 40, 51, 452274),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 42, 7, 734568),
#   'Duration': datetime.timedelta(microseconds=548949),
#   'Size': 322420,
#   'gap': datetime.timedelta(seconds=13, microseconds=188535)},
#  {'linenumber': 2943,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 5, 3, 239504),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 41, 23, 861439),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 42, 52, 724320),
#   'Duration': datetime.timedelta(microseconds=488672),
#   'Size': 183864,
#   'gap': datetime.timedelta(seconds=15, microseconds=119345)},
#  {'linenumber': 2947,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 5, 14, 690062),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 41, 35, 311999),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 42, 53, 212992),
#   'Duration': datetime.timedelta(microseconds=238074),
#   'Size': 89112,
#   'gap': datetime.timedelta(seconds=10, microseconds=961888)},
#  {'linenumber': 3542,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 5, 49, 287425),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 42, 9, 909345),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 43, 38, 420023),
#   'Duration': datetime.timedelta(microseconds=833744),
#   'Size': 413788,
#   'gap': datetime.timedelta(seconds=15, microseconds=473427)},
#  {'linenumber': 3546,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 6, 1, 653367),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 42, 22, 275298),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 43, 39, 253768),
#   'Duration': datetime.timedelta(microseconds=279912),
#   'Size': 188188,
#   'gap': datetime.timedelta(seconds=11, microseconds=532209)},
#  {'linenumber': 3925,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 6, 12, 310714),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 42, 32, 932630),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 44, 9, 232149),
#   'Duration': datetime.timedelta(microseconds=279874),
#   'Size': 156228,
#   'gap': datetime.timedelta(seconds=6, microseconds=295200)},
#  {'linenumber': 4080,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 6, 35, 335738),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 42, 55, 957657),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 44, 24, 499379),
#   'Duration': datetime.timedelta(microseconds=339457),
#   'Size': 228044,
#   'gap': datetime.timedelta(seconds=15, microseconds=442549)},
#  {'linenumber': 4084,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 6, 48, 746564),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 43, 9, 368480),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 44, 24, 838836),
#   'Duration': datetime.timedelta(microseconds=384492),
#   'Size': 238760,
#   'gap': datetime.timedelta(seconds=13, microseconds=71366)},
#  {'linenumber': 4631,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 7, 21, 381460),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 43, 42, 3362),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 45, 9, 615241),
#   'Duration': datetime.timedelta(microseconds=540677),
#   'Size': 280308,
#   'gap': datetime.timedelta(seconds=16, microseconds=370441)},
#  {'linenumber': 4635,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 7, 32, 286765),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 43, 52, 908694),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 45, 10, 155918),
#   'Duration': datetime.timedelta(microseconds=583328),
#   'Size': 288580,
#   'gap': datetime.timedelta(seconds=10, microseconds=364655)},
#  {'linenumber': 5174,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 8, 7, 429579),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 44, 28, 51513),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 45, 55, 250116),
#   'Duration': datetime.timedelta(microseconds=444196),
#   'Size': 302116,
#   'gap': datetime.timedelta(seconds=16, microseconds=779846)},
#  {'linenumber': 5178,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 8, 19, 146727),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 44, 39, 768646),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 45, 55, 694313),
#   'Duration': datetime.timedelta(microseconds=159088),
#   'Size': 99640,
#   'gap': datetime.timedelta(seconds=11, microseconds=272937)},
#  {'linenumber': 5614,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 8, 30, 450603),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 44, 51, 72510),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 46, 25, 340732),
#   'Duration': datetime.timedelta(microseconds=379397),
#   'Size': 229548,
#   'gap': datetime.timedelta(seconds=6, microseconds=902487)},
#  {'linenumber': 5963,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 8, 53, 474308),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 45, 14, 96214),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 46, 55, 428746),
#   'Duration': datetime.timedelta(microseconds=825684),
#   'Size': 389348,
#   'gap': datetime.timedelta(seconds=2, microseconds=647625)},
#  {'linenumber': 6193,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 9, 16, 497507),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 45, 37, 119421),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 47, 11, 93266),
#   'Duration': datetime.timedelta(microseconds=552306),
#   'Size': 359080,
#   'gap': datetime.timedelta(seconds=10, microseconds=8797)},
#  {'linenumber': 6197,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 9, 24, 551862),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 45, 45, 173787),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 47, 11, 645573),
#   'Duration': datetime.timedelta(microseconds=331119),
#   'Size': 197964,
#   'gap': datetime.timedelta(seconds=7, microseconds=502060)},
#  {'linenumber': 6462,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 9, 39, 524503),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 46, 0, 146447),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 47, 41, 882998),
#   'Duration': datetime.timedelta(microseconds=495868),
#   'Size': 331068,
#   'gap': datetime.timedelta(seconds=2, microseconds=242230)},
#  {'linenumber': 6610,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 10, 2, 548296),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 46, 23, 170215),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 47, 57, 185545),
#   'Duration': datetime.timedelta(microseconds=529326),
#   'Size': 426948,
#   'gap': datetime.timedelta(seconds=9, microseconds=964275)},
#  {'linenumber': 6614,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 10, 10, 163218),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 46, 30, 785169),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 47, 57, 714872),
#   'Duration': datetime.timedelta(microseconds=467996),
#   'Size': 341972,
#   'gap': datetime.timedelta(seconds=7, microseconds=85628)},
#  {'linenumber': 6959,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 10, 25, 574200),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 46, 46, 196126),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 48, 28, 47073),
#   'Duration': datetime.timedelta(microseconds=389355),
#   'Size': 210560,
#   'gap': datetime.timedelta(seconds=2, microseconds=125982)},
#  {'linenumber': 7098,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 10, 48, 596288),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 47, 9, 218221),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 48, 43, 432862),
#   'Duration': datetime.timedelta(microseconds=390995),
#   'Size': 231052,
#   'gap': datetime.timedelta(seconds=9, microseconds=764857)},
#  {'linenumber': 7102,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 10, 54, 815258),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 47, 15, 437167),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 48, 43, 823858),
#   'Duration': datetime.timedelta(microseconds=598785),
#   'Size': 328248,
#   'gap': datetime.timedelta(seconds=5, microseconds=827951)},
#  {'linenumber': 7495,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 11, 11, 620840),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 47, 32, 242765),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 49, 13, 902130),
#   'Duration': datetime.timedelta(microseconds=537312),
#   'Size': 250604,
#   'gap': datetime.timedelta(seconds=2, microseconds=324343)},
#  {'linenumber': 7657,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 11, 34, 644375),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 47, 55, 266317),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 49, 29, 349552),
#   'Duration': datetime.timedelta(microseconds=662823),
#   'Size': 411908,
#   'gap': datetime.timedelta(seconds=9, microseconds=897684)},
#  {'linenumber': 7661,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 11, 42, 871889),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 48, 3, 493815),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 49, 30, 12376),
#   'Duration': datetime.timedelta(microseconds=303513),
#   'Size': 186684,
#   'gap': datetime.timedelta(seconds=7, microseconds=564675)},
#  {'linenumber': 7963,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 11, 57, 669115),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 48, 18, 291057),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 50, 0, 114659),
#   'Duration': datetime.timedelta(microseconds=351381),
#   'Size': 228984,
#   'gap': datetime.timedelta(seconds=2, microseconds=158674)},
#  {'linenumber': 8136,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 12, 20, 692038),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 48, 41, 313945),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 50, 15, 99558),
#   'Duration': datetime.timedelta(microseconds=457987),
#   'Size': 260192,
#   'gap': datetime.timedelta(seconds=10, microseconds=195803)},
#  {'linenumber': 8140,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 12, 27, 760270),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 48, 47, 697940),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 50, 15, 557546),
#   'Duration': datetime.timedelta(microseconds=541358),
#   'Size': 296852,
#   'gap': datetime.timedelta(seconds=5, microseconds=926008)},
#  {'linenumber': 8518,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 12, 43, 718609),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 49, 4, 340538),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 50, 45, 750998),
#   'Duration': datetime.timedelta(microseconds=309388),
#   'Size': 187060,
#   'gap': datetime.timedelta(seconds=2, microseconds=573308)},
#  {'linenumber': 8655,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 13, 6, 740294),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 49, 27, 362232),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 51, 0, 857482),
#   'Duration': datetime.timedelta(microseconds=327989),
#   'Size': 192700,
#   'gap': datetime.timedelta(seconds=10, microseconds=487240)},
#  {'linenumber': 8659,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 13, 16, 876607),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 49, 37, 498535),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 51, 1, 185472),
#   'Duration': datetime.timedelta(microseconds=468776),
#   'Size': 254176,
#   'gap': datetime.timedelta(seconds=9, microseconds=808314)},
#  {'linenumber': 9012,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 13, 29, 762824),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 49, 50, 384739),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 51, 31, 259470),
#   'Duration': datetime.timedelta(microseconds=582942),
#   'Size': 277112,
#   'gap': datetime.timedelta(seconds=3, microseconds=107266)},
#  {'linenumber': 9178,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 13, 52, 789028),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 50, 13, 410960),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 51, 46, 363012),
#   'Duration': datetime.timedelta(microseconds=491281),
#   'Size': 279180,
#   'gap': datetime.timedelta(seconds=11, microseconds=29418)},
#  {'linenumber': 9182,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 14, 3, 977400),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 50, 24, 599324),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 51, 46, 854294),
#   'Duration': datetime.timedelta(microseconds=483557),
#   'Size': 273728,
#   'gap': datetime.timedelta(seconds=10, microseconds=697083)},
#  {'linenumber': 9448,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 14, 15, 811594),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 50, 36, 433512),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 52, 16, 318067),
#   'Duration': datetime.timedelta(microseconds=797306),
#   'Size': 472256,
#   'gap': datetime.timedelta(seconds=4, microseconds=95095)},
#  {'linenumber': 9622,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 14, 38, 836415),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 50, 59, 458354),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 52, 31, 760016),
#   'Duration': datetime.timedelta(microseconds=518034),
#   'Size': 298544,
#   'gap': datetime.timedelta(seconds=11, microseconds=682077)},
#  {'linenumber': 9626,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 14, 51, 325796),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 51, 11, 947718),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 52, 32, 278051),
#   'Duration': datetime.timedelta(microseconds=531905),
#   'Size': 275232,
#   'gap': datetime.timedelta(seconds=11, microseconds=971330)},
#  {'linenumber': 9947,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 15, 1, 859978),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 51, 22, 481917),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 53, 2, 258653),
#   'Duration': datetime.timedelta(microseconds=684617),
#   'Size': 412660,
#   'gap': datetime.timedelta(seconds=4, microseconds=60839)},
#  {'linenumber': 10090,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 15, 24, 884991),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 51, 45, 506915),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 53, 17, 698565),
#   'Duration': datetime.timedelta(microseconds=555331),
#   'Size': 291776,
#   'gap': datetime.timedelta(seconds=11, microseconds=790822)},
#  {'linenumber': 10094,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 15, 36, 827173),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 51, 57, 449077),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 53, 18, 253897),
#   'Duration': datetime.timedelta(microseconds=934369),
#   'Size': 400816,
#   'gap': datetime.timedelta(seconds=11, microseconds=386831)},
#  {'linenumber': 10491,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 15, 47, 909363),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 52, 8, 531290),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 53, 48, 67385),
#   'Duration': datetime.timedelta(microseconds=331310),
#   'Size': 226540,
#   'gap': datetime.timedelta(seconds=2, microseconds=142999)},
#  {'linenumber': 10657,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 16, 10, 932321),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 52, 31, 554263),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 54, 2, 995313),
#   'Duration': datetime.timedelta(microseconds=420016),
#   'Size': 342160,
#   'gap': datetime.timedelta(seconds=12, microseconds=534225)},
#  {'linenumber': 10661,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 16, 23, 548401),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 52, 44, 170333),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 54, 3, 415330),
#   'Duration': datetime.timedelta(microseconds=376491),
#   'Size': 326368,
#   'gap': datetime.timedelta(seconds=12, microseconds=196054)},
#  {'linenumber': 11086,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 16, 33, 955319),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 52, 54, 577250),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 54, 33, 782350),
#   'Duration': datetime.timedelta(microseconds=469047),
#   'Size': 278804,
#   'gap': datetime.timedelta(seconds=4, microseconds=775194)},
#  {'linenumber': 11223,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 16, 56, 981642),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 53, 17, 603586),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 54, 48, 887720),
#   'Duration': datetime.timedelta(microseconds=781800),
#   'Size': 456088,
#   'gap': datetime.timedelta(seconds=12, microseconds=700042)},
#  {'linenumber': 11227,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 17, 10, 153095),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 53, 30, 775011),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 54, 49, 669520),
#   'Duration': datetime.timedelta(microseconds=616851),
#   'Size': 390664,
#   'gap': datetime.timedelta(seconds=12, microseconds=389625)},
#  {'linenumber': 11640,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 17, 20, 496200),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 53, 40, 626902),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 55, 19, 490762),
#   'Duration': datetime.timedelta(microseconds=455355),
#   'Size': 249100,
#   'gap': datetime.timedelta(seconds=3, microseconds=537653)},
#  {'linenumber': 11839,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 17, 43, 290910),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 54, 3, 651015),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 55, 34, 612619),
#   'Duration': datetime.timedelta(microseconds=474403),
#   'Size': 304936,
#   'gap': datetime.timedelta(seconds=13, microseconds=14321)},
#  {'linenumber': 11844,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 17, 57, 177385),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 54, 17, 799300),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 55, 35, 87022),
#   'Duration': datetime.timedelta(microseconds=550793),
#   'Size': 395176,
#   'gap': datetime.timedelta(seconds=13, microseconds=673882)},
#  {'linenumber': 12267,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 18, 6, 537160),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 54, 26, 675632),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 56, 4, 950148),
#   'Duration': datetime.timedelta(microseconds=263710),
#   'Size': 120884,
#   'gap': datetime.timedelta(seconds=3, microseconds=198312)},
#  {'linenumber': 12418,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 18, 29, 798810),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 54, 49, 701808),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 56, 19, 894982),
#   'Duration': datetime.timedelta(microseconds=625737),
#   'Size': 299484,
#   'gap': datetime.timedelta(seconds=13, microseconds=788496)},
#  {'linenumber': 12422,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 18, 42, 386849),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 55, 3, 8777),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 56, 20, 520719),
#   'Duration': datetime.timedelta(microseconds=489660),
#   'Size': 271472,
#   'gap': datetime.timedelta(seconds=12, microseconds=681232)},
#  {'linenumber': 12851,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 18, 52, 103361),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 55, 12, 725305),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 56, 50, 297692),
#   'Duration': datetime.timedelta(microseconds=374350),
#   'Size': 184992,
#   'gap': datetime.timedelta(seconds=3, microseconds=983951)},
#  {'linenumber': 13062,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 19, 15, 125292),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 55, 35, 747202),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 57, 5, 534053),
#   'Duration': datetime.timedelta(microseconds=323685),
#   'Size': 199468,
#   'gap': datetime.timedelta(seconds=14, microseconds=196436)},
#  {'linenumber': 13066,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 19, 28, 420076),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 55, 49, 41985),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 57, 5, 857738),
#   'Duration': datetime.timedelta(microseconds=563032),
#   'Size': 291964,
#   'gap': datetime.timedelta(seconds=12, microseconds=971098)},
#  {'linenumber': 13418,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 19, 38, 148856),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 55, 58, 770766),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 57, 35, 973319),
#   'Duration': datetime.timedelta(microseconds=507756),
#   'Size': 249100,
#   'gap': datetime.timedelta(seconds=1, microseconds=454895)},
#  {'linenumber': 13610,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 20, 1, 173132),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 56, 21, 795074),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 57, 51, 184450),
#   'Duration': datetime.timedelta(microseconds=523488),
#   'Size': 290272,
#   'gap': datetime.timedelta(seconds=14, microseconds=593811)},
#  {'linenumber': 13615,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 20, 13, 938844),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 56, 34, 560771),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 57, 51, 707938),
#   'Duration': datetime.timedelta(microseconds=444064),
#   'Size': 315464,
#   'gap': datetime.timedelta(seconds=12, microseconds=242209)},
#  {'linenumber': 13970,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 20, 24, 195968),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 56, 44, 817896),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 58, 21, 495721),
#   'Duration': datetime.timedelta(microseconds=481202),
#   'Size': 280120,
#   'gap': datetime.timedelta(seconds=4, microseconds=271449)},
#  {'linenumber': 14116,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 20, 47, 219985),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 57, 7, 841890),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 58, 36, 891412),
#   'Duration': datetime.timedelta(microseconds=543038),
#   'Size': 274668,
#   'gap': datetime.timedelta(seconds=14, microseconds=933213)},
#  {'linenumber': 14120,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 21, 0, 529265),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 57, 21, 151172),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 58, 37, 434451),
#   'Duration': datetime.timedelta(microseconds=463652),
#   'Size': 245528,
#   'gap': datetime.timedelta(seconds=12, microseconds=766244)},
#  {'linenumber': 14793,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 21, 33, 266683),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 57, 53, 888595),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 59, 22, 895933),
#   'Duration': datetime.timedelta(microseconds=238533),
#   'Size': 112988,
#   'gap': datetime.timedelta(seconds=12, microseconds=786566)},
#  {'linenumber': 14797,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 21, 40, 323954),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 58, 0, 945863),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 59, 23, 134467),
#   'Duration': datetime.timedelta(microseconds=395804),
#   'Size': 187812,
#   'gap': datetime.timedelta(seconds=6, microseconds=818735)},
#  {'linenumber': 15182,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 21, 56, 288944),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 58, 16, 910848),
#   'PCR': datetime.datetime(1900, 1, 2, 13, 59, 53, 221939),
#   'Duration': datetime.timedelta(microseconds=862501),
#   'Size': 382580,
#   'gap': datetime.timedelta(seconds=2, microseconds=518865)},
#  {'linenumber': 15402,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 22, 19, 309535),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 58, 39, 931445),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 0, 8, 777899),
#   'Duration': datetime.timedelta(microseconds=359876),
#   'Size': 295724,
#   'gap': datetime.timedelta(seconds=15, microseconds=137614)},
#  {'linenumber': 15406,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 22, 32, 687504),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 58, 53, 309421),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 0, 9, 137776),
#   'Duration': datetime.timedelta(microseconds=434486),
#   'Size': 333700,
#   'gap': datetime.timedelta(seconds=13, microseconds=18100)},
#  {'linenumber': 15948,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 23, 5, 357424),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 59, 25, 979329),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 0, 54, 316196),
#   'Duration': datetime.timedelta(microseconds=584410),
#   'Size': 372616,
#   'gap': datetime.timedelta(seconds=15, microseconds=645118)},
#  {'linenumber': 15952,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 23, 17, 130656),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 59, 37, 752559),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 0, 54, 900606),
#   'Duration': datetime.timedelta(microseconds=337368),
#   'Size': 210936,
#   'gap': datetime.timedelta(seconds=11, microseconds=188820)},
#  {'linenumber': 16350,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 23, 28, 380866),
#   'timestamp': datetime.datetime(1900, 1, 2, 13, 59, 49, 2770),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 1, 25, 145353),
#   'Duration': datetime.timedelta(microseconds=458516),
#   'Size': 278992,
#   'gap': datetime.timedelta(seconds=3, microseconds=5411)},
#  {'linenumber': 16548,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 23, 51, 405187),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 0, 12, 27091),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 1, 40, 206834),
#   'Duration': datetime.timedelta(microseconds=422502),
#   'Size': 173148,
#   'gap': datetime.timedelta(seconds=15, microseconds=805809)},
#  {'linenumber': 16552,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 24, 3, 774385),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 0, 24, 396302),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 1, 40, 629337),
#   'Duration': datetime.timedelta(microseconds=478075),
#   'Size': 196272,
#   'gap': datetime.timedelta(seconds=11, microseconds=946709)},
#  {'linenumber': 17257,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 24, 37, 453579),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 0, 58, 75484),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 2, 25, 918936),
#   'Duration': datetime.timedelta(microseconds=490620),
#   'Size': 289896,
#   'gap': datetime.timedelta(seconds=14, microseconds=930168)},
#  {'linenumber': 17262,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 24, 47, 327713),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 1, 7, 949617),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 2, 26, 409557),
#   'Duration': datetime.timedelta(microseconds=497450),
#   'Size': 301552,
#   'gap': datetime.timedelta(seconds=9, microseconds=383513)},
#  {'linenumber': 17723,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 25, 23, 502491),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 1, 44, 124403),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 3, 11, 583783),
#   'Duration': datetime.timedelta(microseconds=469939),
#   'Size': 198716,
#   'gap': datetime.timedelta(seconds=16, microseconds=524648)},
#  {'linenumber': 17727,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 25, 34, 151633),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 1, 54, 773541),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 3, 12, 53723),
#   'Duration': datetime.timedelta(microseconds=549905),
#   'Size': 236504,
#   'gap': datetime.timedelta(seconds=10, microseconds=179199)},
#  {'linenumber': 18034,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 25, 46, 525967),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 2, 7, 147875),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 3, 42, 46401),
#   'Duration': datetime.timedelta(microseconds=482627),
#   'Size': 268088,
#   'gap': datetime.timedelta(seconds=3, microseconds=982262)},
#  {'linenumber': 18420,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 26, 9, 548080),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 2, 30, 169982),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 4, 12, 774957),
#   'Duration': datetime.timedelta(microseconds=574016),
#   'Size': 252296,
#   'gap': datetime.timedelta(seconds=1, microseconds=380009)},
#  {'linenumber': 18622,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 26, 32, 573209),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 2, 53, 195115),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 4, 28, 326271),
#   'Duration': datetime.timedelta(microseconds=405104),
#   'Size': 203416,
#   'gap': datetime.timedelta(seconds=8, microseconds=852084)},
#  {'linenumber': 18978,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 26, 55, 597399),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 3, 16, 219309),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 4, 58, 413362),
#   'Duration': datetime.timedelta(microseconds=627162),
#   'Size': 276924,
#   'gap': datetime.timedelta(seconds=1, microseconds=788195)},
#  {'linenumber': 19122,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 27, 18, 622719),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 3, 39, 244623),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 5, 13, 906278),
#   'Duration': datetime.timedelta(microseconds=500149),
#   'Size': 253236,
#   'gap': datetime.timedelta(seconds=9, microseconds=322434)},
#  {'linenumber': 19126,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 27, 21, 273202),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 3, 41, 895118),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 5, 14, 406428),
#   'Duration': datetime.timedelta(microseconds=500483),
#   'Size': 263952,
#   'gap': datetime.timedelta(seconds=2, microseconds=150346)},
#  {'linenumber': 19699,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 28, 4, 669072),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 4, 25, 290977),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 5, 59, 920505),
#   'Duration': datetime.timedelta(microseconds=583540),
#   'Size': 257936,
#   'gap': datetime.timedelta(seconds=9, microseconds=357901)},
#  {'linenumber': 20092,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 28, 27, 689273),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 4, 48, 311175),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 6, 30, 127933),
#   'Duration': datetime.timedelta(microseconds=543003),
#   'Size': 246844,
#   'gap': datetime.timedelta(seconds=2, microseconds=165880)},
#  {'linenumber': 20258,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 28, 50, 713450),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 5, 11, 335355),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 6, 45, 646382),
#   'Duration': datetime.timedelta(microseconds=469712),
#   'Size': 230488,
#   'gap': datetime.timedelta(seconds=9, microseconds=672283)},
#  {'linenumber': 20262,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 28, 55, 793370),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 5, 16, 415275),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 6, 46, 116094),
#   'Duration': datetime.timedelta(microseconds=514703),
#   'Size': 253236,
#   'gap': datetime.timedelta(seconds=4, microseconds=610208)},
#  {'linenumber': 20794,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 29, 36, 761999),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 5, 57, 383907),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 7, 31, 445228),
#   'Duration': datetime.timedelta(microseconds=424491),
#   'Size': 224660,
#   'gap': datetime.timedelta(seconds=9, microseconds=922872)},
#  {'linenumber': 21223,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 29, 59, 785372),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 6, 20, 407281),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 8, 1, 563176),
#   'Duration': datetime.timedelta(microseconds=474760),
#   'Size': 269780,
#   'gap': datetime.timedelta(seconds=2, microseconds=827766)},
#  {'linenumber': 21427,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 30, 22, 809441),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 6, 43, 431348),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 8, 16, 572122),
#   'Duration': datetime.timedelta(microseconds=544539),
#   'Size': 313208,
#   'gap': datetime.timedelta(seconds=10, microseconds=844077)},
#  {'linenumber': 21431,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 30, 32, 956638),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 6, 53, 578554),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 8, 17, 116661),
#   'Duration': datetime.timedelta(microseconds=526347),
#   'Size': 299484,
#   'gap': datetime.timedelta(seconds=9, microseconds=602667)},
#  {'linenumber': 21977,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 31, 8, 857504),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 7, 29, 479409),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 9, 2, 375802),
#   'Duration': datetime.timedelta(microseconds=453231),
#   'Size': 253236,
#   'gap': datetime.timedelta(seconds=11, microseconds=88430)},
#  {'linenumber': 21981,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 31, 13, 673560),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 7, 34, 295466),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 9, 2, 829034),
#   'Duration': datetime.timedelta(microseconds=654701),
#   'Size': 352124,
#   'gap': datetime.timedelta(seconds=4, microseconds=362826)},
#  {'linenumber': 22396,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 31, 31, 881341),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 7, 52, 503247),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 9, 32, 830385),
#   'Duration': datetime.timedelta(microseconds=542693),
#   'Size': 336332,
#   'gap': datetime.timedelta(seconds=2, microseconds=386251)},
#  {'linenumber': 22549,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 31, 54, 905590),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 8, 15, 527497),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 9, 47, 688995),
#   'Duration': datetime.timedelta(microseconds=736897),
#   'Size': 393484,
#   'gap': datetime.timedelta(seconds=11, microseconds=821704)},
#  {'linenumber': 22553,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 32, 6, 654795),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 8, 27, 276701),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 9, 48, 425892),
#   'Duration': datetime.timedelta(microseconds=450085),
#   'Size': 269780,
#   'gap': datetime.timedelta(seconds=11, microseconds=12307)},
#  {'linenumber': 22840,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 32, 17, 930249),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 8, 38, 552165),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 10, 18, 483347),
#   'Duration': datetime.timedelta(microseconds=700180),
#   'Size': 484288,
#   'gap': datetime.timedelta(seconds=4, microseconds=52124)},
#  {'linenumber': 22980,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 32, 40, 954792),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 9, 1, 576701),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 10, 34, 87348),
#   'Duration': datetime.timedelta(microseconds=518027),
#   'Size': 346484,
#   'gap': datetime.timedelta(seconds=11, microseconds=470996)},
#  {'linenumber': 22984,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 32, 52, 372626),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 9, 12, 994545),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 10, 34, 605376),
#   'Duration': datetime.timedelta(microseconds=545842),
#   'Size': 380512,
#   'gap': datetime.timedelta(seconds=10, microseconds=899817)},
#  {'linenumber': 23377,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 33, 26, 998114),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 9, 47, 620019),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 11, 19, 634805),
#   'Duration': datetime.timedelta(microseconds=521689),
#   'Size': 316968,
#   'gap': datetime.timedelta(seconds=11, microseconds=968965)},
#  {'linenumber': 23381,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 33, 35, 275774),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 9, 55, 897680),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 11, 20, 156494),
#   'Duration': datetime.timedelta(microseconds=464253),
#   'Size': 287264,
#   'gap': datetime.timedelta(seconds=7, microseconds=755972)},
#  {'linenumber': 23834,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 34, 13, 455330),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 10, 33, 667437),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 12, 5, 493935),
#   'Duration': datetime.timedelta(microseconds=580252),
#   'Size': 359456,
#   'gap': datetime.timedelta(seconds=12, microseconds=156161)},
#  {'linenumber': 23838,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 34, 23, 725550),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 10, 43, 694466),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 12, 6, 74187),
#   'Duration': datetime.timedelta(microseconds=327235),
#   'Size': 197964,
#   'gap': datetime.timedelta(seconds=9, microseconds=446777)},
#  {'linenumber': 24295,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 34, 36, 702970),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 10, 56, 692203),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 12, 35, 857085),
#   'Duration': datetime.timedelta(microseconds=365687),
#   'Size': 233308,
#   'gap': datetime.timedelta(seconds=4, microseconds=815945)},
#  {'linenumber': 24437,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 34, 59, 942860),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 11, 19, 716192),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 12, 50, 963505),
#   'Duration': datetime.timedelta(microseconds=481356),
#   'Size': 328060,
#   'gap': datetime.timedelta(seconds=12, microseconds=735272)},
#  {'linenumber': 24441,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 35, 12, 381390),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 11, 33, 3300),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 12, 51, 444861),
#   'Duration': datetime.timedelta(microseconds=319166),
#   'Size': 212064,
#   'gap': datetime.timedelta(seconds=12, microseconds=805752)},
#  {'linenumber': 24829,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 35, 45, 141900),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 12, 5, 763805),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 13, 36, 544254),
#   'Duration': datetime.timedelta(microseconds=531809),
#   'Size': 254928,
#   'gap': datetime.timedelta(seconds=13, microseconds=203829)},
#  {'linenumber': 24833,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 35, 54, 388997),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 12, 15, 10907),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 13, 37, 76063),
#   'Duration': datetime.timedelta(microseconds=570681),
#   'Size': 295348,
#   'gap': datetime.timedelta(seconds=8, microseconds=715293)},
#  {'linenumber': 25395,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 36, 31, 189902),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 12, 51, 811807),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 14, 22, 469921),
#   'Duration': datetime.timedelta(microseconds=501668),
#   'Size': 215448,
#   'gap': datetime.timedelta(seconds=13, microseconds=324876)},
#  {'linenumber': 25400,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 36, 40, 443646),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 13, 1, 65550),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 14, 22, 971589),
#   'Duration': datetime.timedelta(microseconds=644662),
#   'Size': 297792,
#   'gap': datetime.timedelta(seconds=8, microseconds=752075)},
#  {'linenumber': 25833,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 37, 17, 237544),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 13, 37, 859453),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 15, 8, 560493),
#   'Duration': datetime.timedelta(microseconds=493060),
#   'Size': 306440,
#   'gap': datetime.timedelta(seconds=13, microseconds=283138)},
#  {'linenumber': 25837,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 37, 27, 441859),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 13, 48, 63765),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 15, 9, 53554),
#   'Duration': datetime.timedelta(microseconds=477763),
#   'Size': 279744,
#   'gap': datetime.timedelta(seconds=9, microseconds=711252)},
#  {'linenumber': 26111,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 37, 40, 262839),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 14, 0, 884746),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 15, 38, 984996),
#   'Duration': datetime.timedelta(microseconds=417272),
#   'Size': 312832,
#   'gap': datetime.timedelta(seconds=3, microseconds=318716)},
#  {'linenumber': 26249,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 38, 3, 286616),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 14, 23, 908550),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 15, 54, 277664),
#   'Duration': datetime.timedelta(microseconds=422147),
#   'Size': 287640,
#   'gap': datetime.timedelta(seconds=13, microseconds=613669)},
#  {'linenumber': 26253,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 38, 16, 314167),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 14, 36, 936089),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 15, 54, 699812),
#   'Duration': datetime.timedelta(microseconds=404866),
#   'Size': 261696,
#   'gap': datetime.timedelta(seconds=12, microseconds=605392)},
#  {'linenumber': 26848,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 38, 49, 329434),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 15, 9, 951338),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 16, 39, 979326),
#   'Duration': datetime.timedelta(microseconds=446631),
#   'Size': 316780,
#   'gap': datetime.timedelta(seconds=13, microseconds=954386)},
#  {'linenumber': 26852,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 39, 0, 373029),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 15, 20, 994941),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 16, 40, 425958),
#   'Duration': datetime.timedelta(microseconds=466174),
#   'Size': 320352,
#   'gap': datetime.timedelta(seconds=10, microseconds=596972)},
#  {'linenumber': 27173,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 39, 12, 354686),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 15, 32, 976592),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 17, 10, 307795),
#   'Duration': datetime.timedelta(microseconds=482000),
#   'Size': 333888,
#   'gap': datetime.timedelta(seconds=1, microseconds=331213)},
#  {'linenumber': 27314,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 39, 35, 377631),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 15, 55, 999536),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 17, 25, 675734),
#   'Duration': datetime.timedelta(microseconds=520069),
#   'Size': 356072,
#   'gap': datetime.timedelta(seconds=14, microseconds=306988)},
#  {'linenumber': 27318,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 39, 47, 589817),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 16, 8, 211726),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 17, 26, 195803),
#   'Duration': datetime.timedelta(microseconds=433729),
#   'Size': 286700,
#   'gap': datetime.timedelta(seconds=11, microseconds=692121)},
#  {'linenumber': 27709,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 40, 21, 425799),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 16, 42, 47703),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 18, 11, 502178),
#   'Duration': datetime.timedelta(microseconds=395295),
#   'Size': 201348,
#   'gap': datetime.timedelta(seconds=14, microseconds=528981)},
#  {'linenumber': 27713,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 40, 32, 476873),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 16, 53, 98777),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 18, 11, 897473),
#   'Duration': datetime.timedelta(microseconds=417614),
#   'Size': 215448,
#   'gap': datetime.timedelta(seconds=10, microseconds=655779)},
#  {'linenumber': 28347,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 41, 7, 473613),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 17, 28, 95517),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 18, 56, 953700),
#   'Duration': datetime.timedelta(microseconds=612852),
#   'Size': 290460,
#   'gap': datetime.timedelta(seconds=14, microseconds=533643)},
#  {'linenumber': 28351,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 41, 18, 968824),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 17, 39, 590725),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 18, 57, 566552),
#   'Duration': datetime.timedelta(microseconds=455486),
#   'Size': 224848,
#   'gap': datetime.timedelta(seconds=10, microseconds=882356)},
#  {'linenumber': 28859,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 41, 53, 523936),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 18, 14, 145853),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 19, 42, 698379),
#   'Duration': datetime.timedelta(microseconds=609879),
#   'Size': 275796,
#   'gap': datetime.timedelta(seconds=15, microseconds=430877)},
#  {'linenumber': 28863,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 42, 4, 182097),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 18, 24, 804009),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 19, 43, 308259),
#   'Duration': datetime.timedelta(microseconds=648265),
#   'Size': 307380,
#   'gap': datetime.timedelta(seconds=10, microseconds=48277)},
#  {'linenumber': 29253,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 42, 16, 546650),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 18, 37, 168558),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 20, 13, 349647),
#   'Duration': datetime.timedelta(microseconds=389149),
#   'Size': 234248,
#   'gap': datetime.timedelta(seconds=1, microseconds=49279)},
#  {'linenumber': 29475,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 42, 39, 569403),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 19, 0, 191309),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 20, 28, 519525),
#   'Duration': datetime.timedelta(microseconds=613520),
#   'Size': 383332,
#   'gap': datetime.timedelta(seconds=15, microseconds=655428)},
#  {'linenumber': 29479,
#   'wallclock': datetime.datetime(2019, 11, 10, 0, 42, 51, 814193),
#   'timestamp': datetime.datetime(1900, 1, 2, 14, 19, 12, 436104),
#   'PCR': datetime.datetime(1900, 1, 2, 14, 20, 29, 133045),
#   'Duration': datetime.timedelta(microseconds=505878),
#   'Size': 357764,
#   'gap': datetime.timedelta(seconds=11, microseconds=631275)},
#  {'linenumber': 30091,
# ...
#   'Duration': datetime.timedelta(microseconds=442995),
#   'Size': 249288,
#   'gap': datetime.timedelta(seconds=10, microseconds=496076)},
#  {'linenumber': 201544,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 39, 12, 266722),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 15, 32, 888647),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 16, 56, 922432),
#   'Duration': datetime.timedelta(microseconds=340510),
#   'Size': 184804,
#   'gap': datetime.timedelta(seconds=9, microseconds=450689)},
#  {'linenumber': 201928,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 39, 25, 395499),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 15, 46, 17412),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 17, 26, 939637),
#   'Duration': datetime.timedelta(microseconds=517003),
#   'Size': 403636,
#   'gap': datetime.timedelta(seconds=3, microseconds=59248)},
#  {'linenumber': 202137,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 39, 48, 420603),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 16, 9, 42527),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 17, 42, 353386),
#   'Duration': datetime.timedelta(microseconds=413186),
#   'Size': 247596,
#   'gap': datetime.timedelta(seconds=10, microseconds=670465)},
#  {'linenumber': 202142,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 39, 57, 951478),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 16, 18, 573387),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 17, 42, 766573),
#   'Duration': datetime.timedelta(microseconds=510382),
#   'Size': 309448,
#   'gap': datetime.timedelta(seconds=9, microseconds=117674)},
#  {'linenumber': 202543,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 40, 11, 444414),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 16, 32, 66352),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 18, 12, 244635),
#   'Duration': datetime.timedelta(microseconds=780240),
#   'Size': 373744,
#   'gap': datetime.timedelta(seconds=3, microseconds=804077)},
#  {'linenumber': 202690,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 40, 34, 467953),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 16, 55, 89874),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 18, 27, 548238),
#   'Duration': datetime.timedelta(microseconds=611511),
#   'Size': 290084,
#   'gap': datetime.timedelta(seconds=11, microseconds=525799)},
#  {'linenumber': 202694,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 40, 46, 663786),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 17, 7, 285693),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 18, 28, 159750),
#   'Duration': datetime.timedelta(microseconds=641825),
#   'Size': 331444,
#   'gap': datetime.timedelta(seconds=11, microseconds=584308)},
#  {'linenumber': 203109,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 40, 57, 490873),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 17, 18, 112798),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 18, 57, 734764),
#   'Duration': datetime.timedelta(microseconds=636026),
#   'Size': 318848,
#   'gap': datetime.timedelta(seconds=4, microseconds=49401)},
#  {'linenumber': 203359,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 41, 20, 517393),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 17, 41, 139329),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 19, 13, 234911),
#   'Duration': datetime.timedelta(microseconds=422738),
#   'Size': 250416,
#   'gap': datetime.timedelta(seconds=11, microseconds=882322)},
#  {'linenumber': 203364,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 41, 33, 581409),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 17, 54, 203337),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 19, 13, 657650),
#   'Duration': datetime.timedelta(microseconds=639928),
#   'Size': 372240,
#   'gap': datetime.timedelta(seconds=12, microseconds=641270)},
#  {'linenumber': 203801,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 41, 43, 541535),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 18, 4, 163474),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 19, 43, 699249),
#   'Duration': datetime.timedelta(microseconds=533255),
#   'Size': 272788,
#   'gap': datetime.timedelta(seconds=4, microseconds=443047)},
#  {'linenumber': 203976,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 42, 6, 565978),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 18, 27, 187901),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 19, 58, 835331),
#   'Duration': datetime.timedelta(microseconds=521093),
#   'Size': 228608,
#   'gap': datetime.timedelta(seconds=12, microseconds=335673)},
#  {'linenumber': 203980,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 42, 19, 988160),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 18, 39, 720740),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 19, 59, 356424),
#   'Duration': datetime.timedelta(microseconds=386230),
#   'Size': 186308,
#   'gap': datetime.timedelta(seconds=12, microseconds=11746)},
#  {'linenumber': 204408,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 42, 29, 589124),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 18, 50, 211053),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 20, 28, 966721),
#   'Duration': datetime.timedelta(microseconds=641078),
#   'Size': 329752,
#   'gap': datetime.timedelta(seconds=2, microseconds=988651)},
#  {'linenumber': 204606,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 42, 52, 613192),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 19, 13, 235120),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 20, 44, 463504),
#   'Duration': datetime.timedelta(microseconds=717933),
#   'Size': 322420,
#   'gap': datetime.timedelta(seconds=12, microseconds=752022)},
#  {'linenumber': 204611,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 43, 5, 155618),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 19, 25, 777529),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 20, 45, 181438),
#   'Duration': datetime.timedelta(microseconds=521305),
#   'Size': 270156,
#   'gap': datetime.timedelta(seconds=11, microseconds=824476)},
#  {'linenumber': 205012,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 43, 15, 637130),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 19, 36, 259056),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 21, 15, 455799),
#   'Duration': datetime.timedelta(microseconds=578641),
#   'Size': 341032,
#   'gap': datetime.timedelta(seconds=4, microseconds=780183)},
#  {'linenumber': 205197,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 43, 38, 659679),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 19, 59, 281598),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 21, 30, 510878),
#   'Duration': datetime.timedelta(microseconds=585507),
#   'Size': 284444,
#   'gap': datetime.timedelta(seconds=12, microseconds=754570)},
#  {'linenumber': 205201,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 43, 51, 864599),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 20, 12, 486525),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 21, 31, 96385),
#   'Duration': datetime.timedelta(microseconds=377682),
#   'Size': 201724,
#   'gap': datetime.timedelta(seconds=12, microseconds=619420)},
#  {'linenumber': 205725,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 44, 24, 710266),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 20, 45, 332193),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 22, 16, 486241),
#   'Duration': datetime.timedelta(microseconds=448056),
#   'Size': 207176,
#   'gap': datetime.timedelta(seconds=12, microseconds=826400)},
#  {'linenumber': 205729,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 44, 34, 166766),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 20, 54, 788692),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 22, 16, 934297),
#   'Duration': datetime.timedelta(microseconds=331312),
#   'Size': 149084,
#   'gap': datetime.timedelta(seconds=9, microseconds=8443)},
#  {'linenumber': 206175,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 44, 47, 732530),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 21, 8, 354456),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 22, 47, 404817),
#   'Duration': datetime.timedelta(microseconds=486229),
#   'Size': 288580,
#   'gap': datetime.timedelta(seconds=4, microseconds=929259)},
#  {'linenumber': 206369,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 45, 10, 756489),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 21, 31, 378414),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 23, 2, 556797),
#   'Duration': datetime.timedelta(microseconds=362709),
#   'Size': 204732,
#   'gap': datetime.timedelta(seconds=12, microseconds=805143)},
#  {'linenumber': 206373,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 45, 24, 126130),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 21, 44, 634531),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 23, 2, 919507),
#   'Duration': datetime.timedelta(microseconds=359976),
#   'Size': 205860,
#   'gap': datetime.timedelta(seconds=12, microseconds=893408)},
#  {'linenumber': 206815,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 45, 33, 781630),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 21, 54, 403558),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 23, 33, 48709),
#   'Duration': datetime.timedelta(microseconds=364750),
#   'Size': 195144,
#   'gap': datetime.timedelta(seconds=5, microseconds=269735)},
#  {'linenumber': 207030,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 45, 56, 804571),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 22, 17, 426500),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 23, 48, 373881),
#   'Duration': datetime.timedelta(microseconds=720941),
#   'Size': 367728,
#   'gap': datetime.timedelta(seconds=13, microseconds=32954)},
#  {'linenumber': 207034,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 46, 10, 962758),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 22, 31, 584682),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 23, 49, 94823),
#   'Duration': datetime.timedelta(microseconds=259591),
#   'Size': 130472,
#   'gap': datetime.timedelta(seconds=13, microseconds=437241)},
#  {'linenumber': 207468,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 46, 19, 827404),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 22, 40, 449331),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 24, 19, 384495),
#   'Duration': datetime.timedelta(microseconds=317730),
#   'Size': 208492,
#   'gap': datetime.timedelta(seconds=3, microseconds=867783)},
#  {'linenumber': 207657,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 46, 42, 852852),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 23, 3, 474780),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 24, 34, 607173),
#   'Duration': datetime.timedelta(microseconds=472684),
#   'Size': 237256,
#   'gap': datetime.timedelta(seconds=12, microseconds=848830)},
#  {'linenumber': 207661,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 46, 56, 120101),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 23, 16, 742028),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 24, 35, 79858),
#   'Duration': datetime.timedelta(microseconds=526837),
#   'Size': 268464,
#   'gap': datetime.timedelta(seconds=12, microseconds=794564)},
#  {'linenumber': 208108,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 47, 5, 874589),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 23, 26, 496509),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 25, 5, 182361),
#   'Duration': datetime.timedelta(microseconds=589022),
#   'Size': 324864,
#   'gap': datetime.timedelta(seconds=1, microseconds=234150)},
#  {'linenumber': 208303,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 47, 28, 901040),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 23, 49, 522966),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 25, 20, 432882),
#   'Duration': datetime.timedelta(microseconds=464020),
#   'Size': 220900,
#   'gap': datetime.timedelta(seconds=13, microseconds=69324)},
#  {'linenumber': 208307,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 47, 40, 602116),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 24, 1, 224049),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 25, 20, 896903),
#   'Duration': datetime.timedelta(microseconds=464866),
#   'Size': 215636,
#   'gap': datetime.timedelta(seconds=11, microseconds=237063)},
#  {'linenumber': 208713,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 47, 51, 922942),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 24, 12, 544866),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 25, 50, 900454),
#   'Duration': datetime.timedelta(microseconds=486301),
#   'Size': 263576,
#   'gap': datetime.timedelta(seconds=2, microseconds=281117)},
#  {'linenumber': 208925,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 48, 14, 947388),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 24, 35, 569313),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 26, 6, 156573),
#   'Duration': datetime.timedelta(microseconds=368584),
#   'Size': 189316,
#   'gap': datetime.timedelta(seconds=13, microseconds=393410)},
#  {'linenumber': 208930,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 48, 27, 547035),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 24, 48, 168963),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 26, 6, 525157),
#   'Duration': datetime.timedelta(microseconds=642836),
#   'Size': 330880,
#   'gap': datetime.timedelta(seconds=12, microseconds=231066)},
#  {'linenumber': 209354,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 48, 37, 972138),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 24, 58, 594062),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 26, 36, 722352),
#   'Duration': datetime.timedelta(microseconds=424223),
#   'Size': 307004,
#   'gap': datetime.timedelta(seconds=4, microseconds=635998)},
#  {'linenumber': 209534,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 49, 0, 998066),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 25, 21, 619993),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 26, 52, 57493),
#   'Duration': datetime.timedelta(microseconds=473871),
#   'Size': 356824,
#   'gap': datetime.timedelta(seconds=13, microseconds=537010)},
#  {'linenumber': 209538,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 49, 15, 116302),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 25, 35, 738219),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 26, 52, 531364),
#   'Duration': datetime.timedelta(microseconds=473298),
#   'Size': 309260,
#   'gap': datetime.timedelta(seconds=13, microseconds=644355)},
#  {'linenumber': 209927,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 49, 24, 230290),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 25, 44, 644957),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 27, 22, 925245),
#   'Duration': datetime.timedelta(microseconds=327182),
#   'Size': 224660,
#   'gap': datetime.timedelta(seconds=3, microseconds=982097)},
#  {'linenumber': 210158,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 49, 47, 484180),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 26, 7, 670343),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 27, 37, 663460),
#   'Duration': datetime.timedelta(microseconds=589584),
#   'Size': 307944,
#   'gap': datetime.timedelta(seconds=13, microseconds=985414)},
#  {'linenumber': 210162,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 50, 0, 132759),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 26, 20, 754687),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 27, 38, 253044),
#   'Duration': datetime.timedelta(microseconds=493155),
#   'Size': 277864,
#   'gap': datetime.timedelta(seconds=12, microseconds=494760)},
#  {'linenumber': 210528,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 50, 10, 725320),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 26, 30, 694474),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 28, 7, 997535),
#   'Duration': datetime.timedelta(microseconds=560354),
#   'Size': 308696,
#   'gap': datetime.timedelta(seconds=2, microseconds=564358)},
#  {'linenumber': 210683,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 50, 33, 966060),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 26, 53, 718530),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 28, 23, 534532),
#   'Duration': datetime.timedelta(microseconds=449236),
#   'Size': 304936,
#   'gap': datetime.timedelta(seconds=14, microseconds=158885)},
#  {'linenumber': 210687,
#   'wallclock': datetime.datetime(2019, 11, 10, 4, 50, 46, 283490),
#   'timestamp': datetime.datetime(1900, 1, 2, 18, 27, 6, 650266),
#   'PCR': datetime.datetime(1900, 1, 2, 18, 28, 23, 983769),
#   'Duration': datetime.timedelta(microseconds=213995),
#   'Size': 165816,
#   'gap': datetime.timedelta(seconds=12, microseconds=482500)},
#  ...]

# %%
#Get the playlist for a specific break....
break_number=10

regex_newsegment=r"New segment detected:"
regex_opencom=r"Opening commercial log file: ([\S]*\.m3u8)"
regex_append=r"Detected segment appended to playlist"
regex_segment=r"(http://[\S]*.ts)"
local_feed=[lf for lf in Config.LOCALIZED_FEEDS if lf["dir"]==channel][0]
localizer_log=os.path.join(Config.LOCALIZER_ROOT,"logs","localizer_"+local_feed['log']+'.log')

playlist=[]
new_segment=False
segment=""

with open(localizer_log) as file:
    for line in file:
        match=re.search(regex_newsegment,line)
        if match: # New segment detected
            new_segment=True
        match=re.search(regex_segment,line)
        if match: # link to segment
            segment=match.group(1)
        match=re.search(regex_append,line)
        if match and new_segment and len(segment)>0: # Segment appended to playlist
            playlist.append(segment)
        match=re.search(regex_opencom,line)
        if match:
            line=next(file)
            if not "Keeping regional segments." in line:
                playlist.append(match.group(1))

segment_index=playlist.index([s for s in playlist if "brk_{:02d}".format(break_number) in s][0])
                
print(playlist[segment_index-1])
print(playlist[segment_index])
print(playlist[segment_index+1])
# Out:
# http://129.228.120.86/streams/nicktoons_pol/segment_190328.ts
# /ddrive/streams/nicktoons_bul/commercials/playlists/2019-11-10/brk_10/playlist.m3u8
# http://129.228.120.86/streams/nicktoons_pol/segment_190351.ts

# %%
print(Config.LOCALIZER_ROOT)
